# %%
import os 
import pandas as pd
import numpy as np 
import json
import pymongo

# %%
path = "./data"
os.chdir(path)
files = os.listdir()

# %%
final_list = []
for file in files:
    with open(file) as f:
        try:
            data = json.loads(f.read(), encoding='utf-8')
        except Exception as e:
            print("error in file:",file)
            pass

#         print(data)
        for i in range (len(data["entry"])):
            resource_dict = {}
            temp_list = []
            if data["entry"][i]["resource"]["resourceType"] == "Patient":
                
                resource_dict["resource_type"] = data["entry"][i]["resource"]["resourceType"]
                resource_dict["id"] = data["entry"][i]["resource"]["id"]
                try:
                    resource_dict["identifier"] = data["entry"][i]["resource"]["identifier"]
            #         print(identifier)
                except:
                    pass
                try:
                    resource_dict["active"] = data["entry"][i]["resource"]["active"]
#                     print("active:",active)
                except Exception as e:
            #             print("error:",e)
                    pass
                try:
                    resource_dict["telecom"] = data["entry"][i]["resource"]["telecom"]
                except:
                    pass
                try:
                    resource_dict["name"] = data["entry"][i]["resource"]["name"][0]["given"]
                except:
                    pass
                try:
                    resource_dict["gender"] = data["entry"][i]["resource"]["gender"]
                except:
                    pass
                try:
                    resource_dict["birthDate"] = data["entry"][i]["resource"]["birthDate"]
                except:
                    pass
                try:
                    resource_dict["deceasedBoolean"] = data["entry"][i]["resource"]["deceasedBoolean"]
                except Exception as e:
                    pass
                try:
                    resource_dict["deceasedDateTime"] = data["entry"][i]["resource"]["deceasedDateTime"]
                except Exception as e:
                    pass
                try:
                    resource_dict["address"] = data["entry"][i]["resource"]["address"][0]["line"] # + data["entry"][i]["resource"]["address"][0]["city"]
                    address.append(data["entry"][i]["resource"]["address"][0]["city"])
                    address.append(data["entry"][i]["resource"]["address"][0]["state"])
                    address.append(data["entry"][i]["resource"]["address"][0]["country"])
                    resource_dict["address"] = ",".join(address)
#                     print(address)
                except:
            #         resource_dict["address"] = data["entry"][i]["resource"]["address"][0]["line"]
                    pass
                try:    
                    resource_dict["organization"] = data["entry"][i]["resource"]["organization"]
                except:
                    pass
                try:    
                    resource_dict["period"] = data["entry"][i]["resource"]["period"]
#                     print(period)
                except:
                    pass
                try:    
                    resource_dict["communication"] = data["entry"][i]["resource"]["communication"][0]["language"]["coding"][0]["display"]
#                     print(communication)
                except:
                    pass
                try:    
                    resource_dict["language"] = data["entry"][i]["resource"]["communication"][0]["language"]["coding"][0]["display"]
#                     print(language)
                except:
                    pass   
                try:    
                    resource_dict["preferred"] = data["entry"][i]["resource"]["communication"][0]["language"]["coding"][0]["display"]
#                     print(preferred)
                except:
                    pass 
                final_list.append(resource_dict)
#                 print(final_list)
                i+=1
# Out:
# <ipython-input-3-5f9b29665ecc>:5: DeprecationWarning: 'encoding' is ignored and deprecated. It will be removed in Python 3.9
#   data = json.loads(f.read(), encoding='utf-8')

# %%
final_list
# Out:
# [{'resource_type': 'Patient',
#   'id': '8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-86-2571'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99949530'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X67249552X'}],
#   'telecom': [{'system': 'phone', 'value': '555-152-6034', 'use': 'home'}],
#   'name': ['Aaron697'],
#   'gender': 'male',
#   'birthDate': '1944-08-28',
#   'deceasedDateTime': '1998-08-15T13:05:53+01:00',
#   'address': ['859 Altenwerth Run Unit 88'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '6fa23508-960e-ff22-c3d0-0519a036543b',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '6fa23508-960e-ff22-c3d0-0519a036543b'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '6fa23508-960e-ff22-c3d0-0519a036543b'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-77-5727'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99921904'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X44198863X'}],
#   'telecom': [{'system': 'phone', 'value': '555-455-2751', 'use': 'home'}],
#   'name': ['Aaron697'],
#   'gender': 'male',
#   'birthDate': '2001-06-28',
#   'address': ['736 Dare Mission'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '83524678-9bff-93b7-ef89-d7f5390072ff',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '83524678-9bff-93b7-ef89-d7f5390072ff'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '83524678-9bff-93b7-ef89-d7f5390072ff'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-44-5148'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99936370'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X60269119X'}],
#   'telecom': [{'system': 'phone', 'value': '555-106-9705', 'use': 'home'}],
#   'name': ['Abbey813'],
#   'gender': 'female',
#   'birthDate': '1980-06-10',
#   'address': ['210 Nitzsche Vale Apt 73'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '4e343b0a-8698-b6dd-64c6-c2d2d0959e6e',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '4e343b0a-8698-b6dd-64c6-c2d2d0959e6e'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '4e343b0a-8698-b6dd-64c6-c2d2d0959e6e'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-73-1554'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99984711'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X89811793X'}],
#   'telecom': [{'system': 'phone', 'value': '555-675-9219', 'use': 'home'}],
#   'name': ['Beth967'],
#   'gender': 'female',
#   'birthDate': '1946-05-21',
#   'address': ['606 Reichert Camp'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '6e4ac285-2a8d-a30d-5ecb-e32cb595a876',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '6e4ac285-2a8d-a30d-5ecb-e32cb595a876'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '6e4ac285-2a8d-a30d-5ecb-e32cb595a876'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-92-6896'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99913876'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X18537023X'}],
#   'telecom': [{'system': 'phone', 'value': '555-418-5997', 'use': 'home'}],
#   'name': ['Bette450'],
#   'gender': 'female',
#   'birthDate': '1968-07-07',
#   'address': ['502 Langosh Neck Unit 20'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '1029f880-d3db-f477-9da3-f59c14ed22c6',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '1029f880-d3db-f477-9da3-f59c14ed22c6'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '1029f880-d3db-f477-9da3-f59c14ed22c6'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-73-8746'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99997924'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X22567330X'}],
#   'telecom': [{'system': 'phone', 'value': '555-748-5270', 'use': 'home'}],
#   'name': ['Bill567'],
#   'gender': 'male',
#   'birthDate': '1998-04-30',
#   'address': ['1029 Johnson Manor'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'a18edb30-e93c-8e9b-8e6a-95a651a24a36',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'a18edb30-e93c-8e9b-8e6a-95a651a24a36'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'a18edb30-e93c-8e9b-8e6a-95a651a24a36'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-36-3871'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99974900'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X23972026X'}],
#   'telecom': [{'system': 'phone', 'value': '555-418-2098', 'use': 'home'}],
#   'name': ['Blanch844'],
#   'gender': 'female',
#   'birthDate': '1943-04-23',
#   'address': ['654 Metz Path'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'f406a4e8-821b-0c9a-c8ec-09ad0f1fe9c6',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'f406a4e8-821b-0c9a-c8ec-09ad0f1fe9c6'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'f406a4e8-821b-0c9a-c8ec-09ad0f1fe9c6'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-55-8633'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99966809'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X77311867X'}],
#   'telecom': [{'system': 'phone', 'value': '555-320-9982', 'use': 'home'}],
#   'name': ['Bob965'],
#   'gender': 'male',
#   'birthDate': '1990-10-27',
#   'address': ['531 Dare Tunnel'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'b8c71fe0-e911-205e-19c3-b92e88e5b5a6',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'b8c71fe0-e911-205e-19c3-b92e88e5b5a6'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'b8c71fe0-e911-205e-19c3-b92e88e5b5a6'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-57-6713'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99966092'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X54583141X'}],
#   'telecom': [{'system': 'phone', 'value': '555-640-7436', 'use': 'home'}],
#   'name': ['Bobbi508'],
#   'gender': 'female',
#   'birthDate': '1941-09-27',
#   'address': ['151 Crist Vista'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'e5b7d947-da2b-9cf4-12a0-9eb2cf735330',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'e5b7d947-da2b-9cf4-12a0-9eb2cf735330'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'e5b7d947-da2b-9cf4-12a0-9eb2cf735330'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-64-3140'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99939912'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X9416817X'}],
#   'telecom': [{'system': 'phone', 'value': '555-326-5395', 'use': 'home'}],
#   'name': ['Chase54'],
#   'gender': 'male',
#   'birthDate': '1977-05-12',
#   'address': ['818 Will Village'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'b0478b4f-16f2-af38-d199-44db19304df2',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'b0478b4f-16f2-af38-d199-44db19304df2'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'b0478b4f-16f2-af38-d199-44db19304df2'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-37-5257'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99974524'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X56922751X'}],
#   'telecom': [{'system': 'phone', 'value': '555-950-7518', 'use': 'home'}],
#   'name': ['Chase54'],
#   'gender': 'male',
#   'birthDate': '1976-09-23',
#   'address': ['592 Ferry Knoll'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '0f978b87-8054-e6d3-aa03-20e101ea37c0',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '0f978b87-8054-e6d3-aa03-20e101ea37c0'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '0f978b87-8054-e6d3-aa03-20e101ea37c0'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-12-1352'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99959699'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X8010852X'}],
#   'telecom': [{'system': 'phone', 'value': '555-810-7175', 'use': 'home'}],
#   'name': ['Chelsie189'],
#   'gender': 'female',
#   'birthDate': '1985-10-31',
#   'address': ['610 Skiles Corner'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '64cdd7b0-d5a5-ca8a-4b03-3db12d7534be',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '64cdd7b0-d5a5-ca8a-4b03-3db12d7534be'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '64cdd7b0-d5a5-ca8a-4b03-3db12d7534be'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-43-7373'}],
#   'telecom': [{'system': 'phone', 'value': '555-131-4483', 'use': 'home'}],
#   'name': ['Cherie102'],
#   'gender': 'female',
#   'birthDate': '2014-09-29',
#   'address': ["1009 O'Connell Avenue Unit 34"],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'cced3031-d98c-d870-5dce-f0086d8c7a34',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'cced3031-d98c-d870-5dce-f0086d8c7a34'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'cced3031-d98c-d870-5dce-f0086d8c7a34'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-57-2405'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99944423'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X572225X'}],
#   'telecom': [{'system': 'phone', 'value': '555-419-9987', 'use': 'home'}],
#   'name': ['Deedra511'],
#   'gender': 'female',
#   'birthDate': '1967-04-28',
#   'address': ['601 Stehr Extension'],
#   'communication': 'Vietnamese',
#   'language': 'Vietnamese',
#   'preferred': 'Vietnamese'},
#  {'resource_type': 'Patient',
#   'id': '7c4e1f8e-29e4-f88f-095a-aa6a9f55e6de',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '7c4e1f8e-29e4-f88f-095a-aa6a9f55e6de'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '7c4e1f8e-29e4-f88f-095a-aa6a9f55e6de'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-16-7674'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99994310'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X29560634X'}],
#   'telecom': [{'system': 'phone', 'value': '555-501-4799', 'use': 'home'}],
#   'name': ['Deena887'],
#   'gender': 'female',
#   'birthDate': '1937-10-21',
#   'deceasedDateTime': '2004-09-15T09:22:00+01:00',
#   'address': ['1073 Mertz Track'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '91cf58f9-191c-3a49-a979-2ca64e52c369',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '91cf58f9-191c-3a49-a979-2ca64e52c369'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '91cf58f9-191c-3a49-a979-2ca64e52c369'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-65-5932'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99924979'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X3878422X'}],
#   'telecom': [{'system': 'phone', 'value': '555-326-4619', 'use': 'home'}],
#   'name': ['Delbert384'],
#   'gender': 'male',
#   'birthDate': '1975-02-20',
#   'address': ['103 Monahan Heights Unit 48'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'cf3ce382-cceb-1557-89ac-b751a9e0e65d',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'cf3ce382-cceb-1557-89ac-b751a9e0e65d'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'cf3ce382-cceb-1557-89ac-b751a9e0e65d'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-32-7067'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99971051'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X85172174X'}],
#   'telecom': [{'system': 'phone', 'value': '555-665-1433', 'use': 'home'}],
#   'name': ['Delfina519'],
#   'gender': 'female',
#   'birthDate': '1951-05-04',
#   'address': ['421 Rau Path Unit 37'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '1ba50d39-8105-69de-09de-c6d5358b3cb6',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '1ba50d39-8105-69de-09de-c6d5358b3cb6'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '1ba50d39-8105-69de-09de-c6d5358b3cb6'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-18-8370'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99952013'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X49053901X'}],
#   'telecom': [{'system': 'phone', 'value': '555-662-1542', 'use': 'home'}],
#   'name': ['Delia459'],
#   'gender': 'female',
#   'birthDate': '1974-03-12',
#   'address': ['979 Bednar Village'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'b0f40536-9dc8-2ea0-0bbf-467a69f5e3ad',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'b0f40536-9dc8-2ea0-0bbf-467a69f5e3ad'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'b0f40536-9dc8-2ea0-0bbf-467a69f5e3ad'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-75-7681'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99914793'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X2718076X'}],
#   'telecom': [{'system': 'phone', 'value': '555-884-9015', 'use': 'home'}],
#   'name': ['Della552'],
#   'gender': 'female',
#   'birthDate': '1956-11-05',
#   'address': ['232 Cremin Passage'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '6a15a792-ed41-e1f3-b942-3c2bd4a01ad6',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '6a15a792-ed41-e1f3-b942-3c2bd4a01ad6'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '6a15a792-ed41-e1f3-b942-3c2bd4a01ad6'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-41-9135'}],
#   'telecom': [{'system': 'phone', 'value': '555-871-4223', 'use': 'home'}],
#   'name': ['Delmar187'],
#   'gender': 'male',
#   'birthDate': '2010-01-09',
#   'address': ['122 Mueller Lodge Unit 62'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'bdb76eef-1faf-1ed7-d1ff-553d7df26fb3',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'bdb76eef-1faf-1ed7-d1ff-553d7df26fb3'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'bdb76eef-1faf-1ed7-d1ff-553d7df26fb3'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-40-3074'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99949878'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X18021555X'}],
#   'telecom': [{'system': 'phone', 'value': '555-136-2338', 'use': 'home'}],
#   'name': ['Eveline832'],
#   'gender': 'female',
#   'birthDate': '1960-07-07',
#   'address': ['918 Murray Corner Suite 5'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '8a3247d3-a54c-43f2-2c5d-a8f5e28ff588',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '8a3247d3-a54c-43f2-2c5d-a8f5e28ff588'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '8a3247d3-a54c-43f2-2c5d-a8f5e28ff588'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-99-9746'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99960167'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X68181762X'}],
#   'telecom': [{'system': 'phone', 'value': '555-136-4712', 'use': 'home'}],
#   'name': ['Everett935'],
#   'gender': 'male',
#   'birthDate': '1974-10-12',
#   'address': ['304 Okuneva Alley Apt 39'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '7b3071eb-aacb-0596-d7b5-4abcb83ac2f0',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '7b3071eb-aacb-0596-d7b5-4abcb83ac2f0'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '7b3071eb-aacb-0596-d7b5-4abcb83ac2f0'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-75-9428'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99928369'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X78500050X'}],
#   'telecom': [{'system': 'phone', 'value': '555-103-6796', 'use': 'home'}],
#   'name': ['Everette494'],
#   'gender': 'male',
#   'birthDate': '1978-01-07',
#   'address': ['282 Balistreri Light'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'ac00ac90-9af7-5b4f-aca4-8b1b9990fc1a',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'ac00ac90-9af7-5b4f-aca4-8b1b9990fc1a'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'ac00ac90-9af7-5b4f-aca4-8b1b9990fc1a'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-81-4799'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99958395'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X7797404X'}],
#   'telecom': [{'system': 'phone', 'value': '555-425-6567', 'use': 'home'}],
#   'name': ['Evon528'],
#   'gender': 'female',
#   'birthDate': '2000-10-29',
#   'address': ['947 Howe Annex Apt 40'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '6dcdc387-88f9-758d-260c-4235ac7c269f',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '6dcdc387-88f9-758d-260c-4235ac7c269f'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '6dcdc387-88f9-758d-260c-4235ac7c269f'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-80-9210'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99966419'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X8539782X'}],
#   'telecom': [{'system': 'phone', 'value': '555-567-4343', 'use': 'home'}],
#   'name': ['Genevive999'],
#   'gender': 'female',
#   'birthDate': '1947-10-01',
#   'address': ['714 Heaney Vale Suite 19'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '839e7cf9-b7d6-da6c-70bb-c151bf5c1c61',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '839e7cf9-b7d6-da6c-70bb-c151bf5c1c61'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '839e7cf9-b7d6-da6c-70bb-c151bf5c1c61'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-35-7380'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99944048'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X70094895X'}],
#   'telecom': [{'system': 'phone', 'value': '555-731-9882', 'use': 'home'}],
#   'name': ['Georgann131'],
#   'gender': 'female',
#   'birthDate': '1985-05-02',
#   'address': ['817 Larkin Annex Unit 50'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'd8cb2b2b-fee1-36de-2e1e-0fda2ed1d991',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'd8cb2b2b-fee1-36de-2e1e-0fda2ed1d991'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'd8cb2b2b-fee1-36de-2e1e-0fda2ed1d991'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-37-6950'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99921705'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X82162082X'}],
#   'telecom': [{'system': 'phone', 'value': '555-777-8307', 'use': 'home'}],
#   'name': ['George991'],
#   'gender': 'male',
#   'birthDate': '1913-10-05',
#   'deceasedDateTime': '2004-01-18T09:05:51+00:00',
#   'address': ['483 Lubowitz Bridge'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'e94401de-18ad-e190-9113-ee5ff31b1439',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'e94401de-18ad-e190-9113-ee5ff31b1439'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'e94401de-18ad-e190-9113-ee5ff31b1439'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-51-6424'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99930116'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X86841029X'}],
#   'telecom': [{'system': 'phone', 'value': '555-635-6296', 'use': 'home'}],
#   'name': ['Georgiana151'],
#   'gender': 'female',
#   'birthDate': '1956-07-06',
#   'address': ['211 Wolf Promenade'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'e9200276-eb25-ac87-e3bf-31de7e8d0b1e',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'e9200276-eb25-ac87-e3bf-31de7e8d0b1e'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'e9200276-eb25-ac87-e3bf-31de7e8d0b1e'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-57-6801'}],
#   'telecom': [{'system': 'phone', 'value': '555-811-6629', 'use': 'home'}],
#   'name': ['Georgianna701'],
#   'gender': 'female',
#   'birthDate': '2019-12-28',
#   'address': ['592 Bailey Green'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '0d55a582-07fe-a897-776c-3ab5e48cd457',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '0d55a582-07fe-a897-776c-3ab5e48cd457'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '0d55a582-07fe-a897-776c-3ab5e48cd457'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-20-9087'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99957903'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X4871961X'}],
#   'telecom': [{'system': 'phone', 'value': '555-571-7714', 'use': 'home'}],
#   'name': ['Gilma310'],
#   'gender': 'female',
#   'birthDate': '1960-07-10',
#   'address': ['308 Greenfelder Parade Suite 94'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '0d7ad451-ac1b-dc0e-48bd-e0a8e1de4f15',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '0d7ad451-ac1b-dc0e-48bd-e0a8e1de4f15'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '0d7ad451-ac1b-dc0e-48bd-e0a8e1de4f15'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-82-3377'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99953286'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X57788101X'}],
#   'telecom': [{'system': 'phone', 'value': '555-893-4758', 'use': 'home'}],
#   'name': ['Giuseppe872'],
#   'gender': 'male',
#   'birthDate': '1912-05-06',
#   'deceasedDateTime': '2016-12-19T19:14:50+00:00',
#   'address': ['222 Watsica Fork'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '3d496c42-21f9-8e42-aa2b-d021a1b79d46',
# ...
#   'preferred': 'Spanish'},
#  {'resource_type': 'Patient',
#   'id': 'da6120a6-4557-7db3-b44c-43c38568c119',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'da6120a6-4557-7db3-b44c-43c38568c119'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'da6120a6-4557-7db3-b44c-43c38568c119'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-41-1087'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99974441'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X3441471X'}],
#   'telecom': [{'system': 'phone', 'value': '555-992-6481', 'use': 'home'}],
#   'name': ['Rubi442'],
#   'gender': 'female',
#   'birthDate': '1974-06-13',
#   'address': ['481 Durgan Fort Suite 15'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'ac56a3df-7399-e895-2a6e-6ae757f3f4a5',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'ac56a3df-7399-e895-2a6e-6ae757f3f4a5'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'ac56a3df-7399-e895-2a6e-6ae757f3f4a5'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-96-3011'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99912483'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X5189437X'}],
#   'telecom': [{'system': 'phone', 'value': '555-315-1469', 'use': 'home'}],
#   'name': ['Rubin812'],
#   'gender': 'male',
#   'birthDate': '1996-08-22',
#   'address': ['493 Nader Loaf'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '4a627a30-b963-bd1c-58be-0499f24d9670',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '4a627a30-b963-bd1c-58be-0499f24d9670'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '4a627a30-b963-bd1c-58be-0499f24d9670'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-78-9619'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99960168'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X30108696X'}],
#   'telecom': [{'system': 'phone', 'value': '555-480-6579', 'use': 'home'}],
#   'name': ['Russell422'],
#   'gender': 'male',
#   'birthDate': '1959-03-26',
#   'address': ['1038 Crist Annex'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': 'c8c2969a-32d7-9694-ce15-378ae4d66413',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'c8c2969a-32d7-9694-ce15-378ae4d66413'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'c8c2969a-32d7-9694-ce15-378ae4d66413'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-16-3893'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99982710'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X27254935X'}],
#   'telecom': [{'system': 'phone', 'value': '555-626-7922', 'use': 'home'}],
#   'name': ['Ruthie901'],
#   'gender': 'female',
#   'birthDate': '1976-01-01',
#   'address': ['522 Greenholt Rapid'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '89ba9a77-7aed-6cb8-6795-fb21f0ec237c',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '89ba9a77-7aed-6cb8-6795-fb21f0ec237c'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '89ba9a77-7aed-6cb8-6795-fb21f0ec237c'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-31-7681'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99981576'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X54032680X'}],
#   'telecom': [{'system': 'phone', 'value': '555-202-8080', 'use': 'home'}],
#   'name': ['Sachiko982'],
#   'gender': 'female',
#   'birthDate': '1954-06-17',
#   'address': ['616 Leffler Gardens'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '15201e77-7e36-0667-73bc-013783e57649',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '15201e77-7e36-0667-73bc-013783e57649'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '15201e77-7e36-0667-73bc-013783e57649'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-45-5589'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99986786'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X66801116X'}],
#   'telecom': [{'system': 'phone', 'value': '555-165-4080', 'use': 'home'}],
#   'name': ['Sandee884'],
#   'gender': 'female',
#   'birthDate': '1946-02-17',
#   'address': ['350 Frami Trafficway'],
#   'communication': 'Chinese',
#   'language': 'Chinese',
#   'preferred': 'Chinese'},
#  {'resource_type': 'Patient',
#   'id': 'f38fe4a9-1634-144c-0147-53c0300c1561',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'f38fe4a9-1634-144c-0147-53c0300c1561'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': 'f38fe4a9-1634-144c-0147-53c0300c1561'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-38-3492'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99941117'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X72519883X'}],
#   'telecom': [{'system': 'phone', 'value': '555-827-4969', 'use': 'home'}],
#   'name': ['Sandy901'],
#   'gender': 'male',
#   'birthDate': '1969-04-01',
#   'address': ['511 Grant Heights'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '686e4b2e-1f8d-7018-c335-1604a300121b',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '686e4b2e-1f8d-7018-c335-1604a300121b'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '686e4b2e-1f8d-7018-c335-1604a300121b'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-51-1293'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99927670'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X47498032X'}],
#   'telecom': [{'system': 'phone', 'value': '555-559-4415', 'use': 'home'}],
#   'name': ['Santiago500'],
#   'gender': 'male',
#   'birthDate': '1976-10-22',
#   'address': ['703 Armstrong Estate'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '37d57af4-d27f-fb97-9b5c-a1090f5a57b7',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '37d57af4-d27f-fb97-9b5c-a1090f5a57b7'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '37d57af4-d27f-fb97-9b5c-a1090f5a57b7'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-76-6872'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99998676'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X6602431X'}],
#   'telecom': [{'system': 'phone', 'value': '555-226-3023', 'use': 'home'}],
#   'name': ['Zachery872'],
#   'gender': 'male',
#   'birthDate': '1970-01-04',
#   'address': ['461 Wiza Corner Apt 50'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'},
#  {'resource_type': 'Patient',
#   'id': '4995ca99-2ab9-3b18-a56e-c33d29e53af0',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '4995ca99-2ab9-3b18-a56e-c33d29e53af0'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '4995ca99-2ab9-3b18-a56e-c33d29e53af0'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-86-9904'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99960263'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X44084101X'}],
#   'telecom': [{'system': 'phone', 'value': '555-606-8142', 'use': 'home'}],
#   'name': ['Zane918'],
#   'gender': 'male',
#   'birthDate': '1950-08-27',
#   'deceasedDateTime': '2013-01-09T01:59:19+00:00',
#   'address': ['563 Bechtelar Wall Suite 1'],
#   'communication': 'English',
#   'language': 'English',
#   'preferred': 'English'}]

# %% [markdown]
# ## Tabular formation( dataframes)

# %%
df = pd.DataFrame(final_list, columns =["resource_type","id","identifier","active",
"telecom","name","gender", "birthDate", "deceasedBoolean","deceasedDateTime" ,"address" , 
 "organization","period","maritalStatus","communication" ])

# %%
df
# Out:
#    resource_type                                    id  \
# 0        Patient  8c95253e-8ee8-9ae8-6d40-021d702dc78e
# 1        Patient  6fa23508-960e-ff22-c3d0-0519a036543b
# 2        Patient  83524678-9bff-93b7-ef89-d7f5390072ff
# 3        Patient  4e343b0a-8698-b6dd-64c6-c2d2d0959e6e
# 4        Patient  6e4ac285-2a8d-a30d-5ecb-e32cb595a876
# ..           ...                                   ...
# 73       Patient  15201e77-7e36-0667-73bc-013783e57649
# 74       Patient  f38fe4a9-1634-144c-0147-53c0300c1561
# 75       Patient  686e4b2e-1f8d-7018-c335-1604a300121b
# 76       Patient  37d57af4-d27f-fb97-9b5c-a1090f5a57b7
# 77       Patient  4995ca99-2ab9-3b18-a56e-c33d29e53af0
#
#                                            identifier  active  \
# 0   [{'system': 'https://github.com/synthetichealt...     NaN
# 1   [{'system': 'https://github.com/synthetichealt...     NaN
# 2   [{'system': 'https://github.com/synthetichealt...     NaN
# 3   [{'system': 'https://github.com/synthetichealt...     NaN
# 4   [{'system': 'https://github.com/synthetichealt...     NaN
# ..                                                ...     ...
# 73  [{'system': 'https://github.com/synthetichealt...     NaN
# 74  [{'system': 'https://github.com/synthetichealt...     NaN
# 75  [{'system': 'https://github.com/synthetichealt...     NaN
# 76  [{'system': 'https://github.com/synthetichealt...     NaN
# 77  [{'system': 'https://github.com/synthetichealt...     NaN
#
#                                               telecom           name  gender  \
# 0   [{'system': 'phone', 'value': '555-152-6034', ...     [Aaron697]    male
# 1   [{'system': 'phone', 'value': '555-455-2751', ...     [Aaron697]    male
# 2   [{'system': 'phone', 'value': '555-106-9705', ...     [Abbey813]  female
# 3   [{'system': 'phone', 'value': '555-675-9219', ...      [Beth967]  female
# 4   [{'system': 'phone', 'value': '555-418-5997', ...     [Bette450]  female
# ..                                                ...            ...     ...
# 73  [{'system': 'phone', 'value': '555-165-4080', ...    [Sandee884]  female
# 74  [{'system': 'phone', 'value': '555-827-4969', ...     [Sandy901]    male
# 75  [{'system': 'phone', 'value': '555-559-4415', ...  [Santiago500]    male
# 76  [{'system': 'phone', 'value': '555-226-3023', ...   [Zachery872]    male
# 77  [{'system': 'phone', 'value': '555-606-8142', ...      [Zane918]    male
#
#      birthDate  deceasedBoolean           deceasedDateTime  \
# 0   1944-08-28              NaN  1998-08-15T13:05:53+01:00
# 1   2001-06-28              NaN                        NaN
# 2   1980-06-10              NaN                        NaN
# 3   1946-05-21              NaN                        NaN
# 4   1968-07-07              NaN                        NaN
# ..         ...              ...                        ...
# 73  1946-02-17              NaN                        NaN
# 74  1969-04-01              NaN                        NaN
# 75  1976-10-22              NaN                        NaN
# 76  1970-01-04              NaN                        NaN
# 77  1950-08-27              NaN  2013-01-09T01:59:19+00:00
#
#                          address  organization  period  maritalStatus  \
# 0   [859 Altenwerth Run Unit 88]           NaN     NaN            NaN
# 1             [736 Dare Mission]           NaN     NaN            NaN
# 2     [210 Nitzsche Vale Apt 73]           NaN     NaN            NaN
# 3            [606 Reichert Camp]           NaN     NaN            NaN
# 4     [502 Langosh Neck Unit 20]           NaN     NaN            NaN
# ..                           ...           ...     ...            ...
# 73        [350 Frami Trafficway]           NaN     NaN            NaN
# 74           [511 Grant Heights]           NaN     NaN            NaN
# 75        [703 Armstrong Estate]           NaN     NaN            NaN
# 76      [461 Wiza Corner Apt 50]           NaN     NaN            NaN
# 77  [563 Bechtelar Wall Suite 1]           NaN     NaN            NaN
#
#    communication
# 0        English
# 1        English
# 2        English
# 3        English
# 4        English
# ..           ...
# 73       Chinese
# 74       English
# 75       English
# 76       English
# 77       English
#
# [78 rows x 15 columns]

# %%
df.to_excel("patients.xlsx")
