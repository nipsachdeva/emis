# %%
import os 
import pandas as pd
import numpy as np 
import json
import pymongo

# %%
# files = os.listdir()
# files

# %%
# for file in files:
file = r"T:\Uni Of Bristol\careers\technical_tests\exa-data-eng-assessment-main\exa-data-eng-assessment-main\emis\code\data\Aaron697_Dickens475_8c95253e-8ee8-9ae8-6d40-021d702dc78e.json"
# df = pd.read_json(file)
print(file)
with open(file) as f:
    data = json.loads(f.read())
#     print(data[0]['text'])
# data
# Out:
# T:\Uni Of Bristol\careers\technical_tests\exa-data-eng-assessment-main\exa-data-eng-assessment-main\emis\code\data\Aaron697_Dickens475_8c95253e-8ee8-9ae8-6d40-021d702dc78e.json

# %%
# len(data["entry"][])

# %%
# data["entry"][0]["resource"]

# %%
length = int(len(data["resourceType"]))
length
# Out:
# 6

# %%
final_list = []
for i in range (len(data["entry"])):
    resource_dict = {}
    temp_list = []
#     resource_type = data["entry"][i]["resource"]["resourceType"]
    resource_dict["resource_type"] = data["entry"][i]["resource"]["resourceType"]
    resource_dict["id"] = data["entry"][i]["resource"]["id"]
    try:
        resource_dict["identifier"] = data["entry"][i]["resource"]["identifier"]
#         print(identifier)
    except:
        pass
    try:
        resource_dict["Medical Record Number"] = data["entry"][i]["resource"]["identifier"][1]["type"]["coding"][0]["display"]
        
        resource_dict["Social Security Number"] = data["entry"][i]["resource"]["identifier"][2]["type"]["coding"][0]["display"]
        resource_dict["Driver's License"] = data["entry"][i]["resource"]["identifier"][3]["type"]["coding"][0]["display"]
    except:
        pass
    
#     try:
#         resource_dict["active"] = data["entry"][i]["resource"]["active"]
#         print("active:",active)
#     except Exception as e:
# #             print("error:",e)
#         pass
    try:
        resource_dict["telecom"] = data["entry"][i]["resource"]["telecom"][0]["value"]
    except:
        pass
#     try:
#         resource_dict["name"] = data["entry"][i]["resource"]["name"][0]["given"]
#     except:
#         pass
#     try:
#         resource_dict["gender"] = data["entry"][i]["resource"]["gender"]
#     except:
#         pass
#     try:
#         resource_dict["birthDate"] = data["entry"][i]["resource"]["birthDate"]
#     except:
#         pass
#     try:
#         resource_dict["deceasedBoolean"] = data["entry"][i]["resource"]["deceasedBoolean"]
#     except Exception as e:
#         pass
#     try:
#         resource_dict["deceasedDateTime"] = data["entry"][i]["resource"]["deceasedDateTime"]
#     except Exception as e:
#         pass
#     try:
#         resource_dict["address"] = data["entry"][i]["resource"]["address"][0]["line"] # + data["entry"][i]["resource"]["address"][0]["city"]
#         address.append(data["entry"][i]["resource"]["address"][0]["city"])
#         address.append(data["entry"][i]["resource"]["address"][0]["state"])
#         address.append(data["entry"][i]["resource"]["address"][0]["country"])
#         resource_dict["address"] = ",".join(address)
#         print(address)
#     except:
# #         resource_dict["address"] = data["entry"][i]["resource"]["address"][0]["line"]
#         pass
#     try:    
#         resource_dict["organization"] = data["entry"][i]["resource"]["organization"]
#     except:
#         pass
#     try:    
#         resource_dict["period"] = data["entry"][i]["resource"]["period"]
#         print(period)
#     except:
#         pass
#     try:    
#         resource_dict["communication"] = data["entry"][i]["resource"]["communication"][0]["language"]["coding"][0]["display"]
#         print(communication)
#     except:
#         pass
#     try:    
#         resource_dict["language"] = data["entry"][i]["resource"]["communication"][0]["language"]["coding"][0]["display"]
#         print(language)
#     except:
#         pass   
#     try:    
#         resource_dict["preferred"] = data["entry"][i]["resource"]["communication"][0]["language"]["coding"][0]["display"]
#         print(preferred)
#     except:
#         pass 
    final_list.append(resource_dict)
    i+=1

# %%
for i in range (1):
#     try:
#         resource_dict["Driver's License"] = data["entry"][1]["resource"]["identifier"]

#     except Exception as e:
#         print(e)
        
    try:
        resource_dict["telecom"] = data["entry"][i]["resource"]["telecom"][0]["value"]
        print(resource_dict)
    except:
        pass
# Out:
# {'resource_type': 'Provenance', 'id': '9cb02794-8917-82ae-340d-177aa8d440c7', 'Medical Record Number': 'Social Security Number', 'Social Security Number': "Driver's License", "Driver's License": [{'use': 'official', 'system': 'https://github.com/synthetichealth/synthea', 'value': '4dbc90e0-b7b2-482c-24af-1405654e59ae'}], 'telecom': '555-152-6034'}

# %%
final_list
# Out:
# [{'resource_type': 'Patient',
#   'id': '8c95253e-8ee8-9ae8-6d40-021d702dc78e',
#   'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#     'value': '8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'MR',
#        'display': 'Medical Record Number'}],
#      'text': 'Medical Record Number'},
#     'system': 'http://hospital.smarthealthit.org',
#     'value': '8c95253e-8ee8-9ae8-6d40-021d702dc78e'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'SS',
#        'display': 'Social Security Number'}],
#      'text': 'Social Security Number'},
#     'system': 'http://hl7.org/fhir/sid/us-ssn',
#     'value': '999-86-2571'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'DL',
#        'display': "Driver's License"}],
#      'text': "Driver's License"},
#     'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#     'value': 'S99949530'},
#    {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203',
#        'code': 'PPN',
#        'display': 'Passport Number'}],
#      'text': 'Passport Number'},
#     'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber',
#     'value': 'X67249552X'}],
#   'Medical Record Number': 'Medical Record Number',
#   'Social Security Number': 'Social Security Number',
#   "Driver's License": "Driver's License",
#   'telecom': '555-152-6034'},
#  {'resource_type': 'Encounter',
#   'id': '4dbc90e0-b7b2-482c-24af-1405654e59ae',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '4dbc90e0-b7b2-482c-24af-1405654e59ae'}]},
#  {'resource_type': 'Condition', 'id': '2b9b5daf-ef78-63c7-3edc-cfc0a209eee0'},
#  {'resource_type': 'Condition', 'id': 'b6487994-9b3f-7b3c-6e2d-feba134129f9'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'f76535a7-ac06-3e3c-d0a3-7285fb4c8dd8'},
#  {'resource_type': 'DocumentReference',
#   'id': 'e3cee541-d578-8b34-d729-3788b4380e40',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:f76535a7-ac06-3e3c-d0a3-7285fb4c8dd8'}]},
#  {'resource_type': 'Claim', 'id': '0121fe66-58dc-78af-0323-6c8702d9d1db'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '8c6a4d7d-8e7c-10f8-9a38-7f7a42049080',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '0121fe66-58dc-78af-0323-6c8702d9d1db'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'fdf63048-be7c-a402-a3c1-e3a4c18b11b8',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'fdf63048-be7c-a402-a3c1-e3a4c18b11b8'}]},
#  {'resource_type': 'Condition', 'id': 'bb2e0c13-7dbe-d38c-2849-94e87c1e8f7e'},
#  {'resource_type': 'Condition', 'id': '57b07326-cf70-bd80-9b0b-fc55c76a0146'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'b606ad82-62ad-e89c-24db-0a03e7689340'},
#  {'resource_type': 'DocumentReference',
#   'id': '5d4c98c8-eb1e-d753-e038-98230915cddd',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:b606ad82-62ad-e89c-24db-0a03e7689340'}]},
#  {'resource_type': 'Claim', 'id': '5f62137b-7644-64f5-f54b-6b516d7a3191'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '91eb6769-cb39-510d-7ab3-642ad4ff4ada',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '5f62137b-7644-64f5-f54b-6b516d7a3191'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'b6c96767-0a76-9d09-7376-b62620228281',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'b6c96767-0a76-9d09-7376-b62620228281'}]},
#  {'resource_type': 'Condition', 'id': '8609343c-7ccd-a020-ab8b-379ebe4e2e20'},
#  {'resource_type': 'Condition', 'id': '96d6dcdd-8694-f570-611c-1f2eca14a4e3'},
#  {'resource_type': 'Condition', 'id': '95fd4de3-2433-a866-f9dd-c24383815c92'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '72314430-f208-4362-aec6-28ed61f052ce'},
#  {'resource_type': 'DocumentReference',
#   'id': '800c36f7-315f-a499-669a-8af3e71c469a',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:72314430-f208-4362-aec6-28ed61f052ce'}]},
#  {'resource_type': 'Claim', 'id': '9c776ce1-4909-bd3d-862f-0a312918861d'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '0396b087-1858-9edc-7d37-3e1d28f354a5',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '9c776ce1-4909-bd3d-862f-0a312918861d'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '9f455824-e938-7b05-4d5b-64a53c0a2cef',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '9f455824-e938-7b05-4d5b-64a53c0a2cef'}]},
#  {'resource_type': 'Condition', 'id': 'a22f9490-97d5-7930-502f-4c404ee963a5'},
#  {'resource_type': 'Condition', 'id': '36bd3b69-7e2e-86df-84e5-4b429e24ee27'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '2aa2808b-1642-8600-b168-d872b430518e'},
#  {'resource_type': 'DocumentReference',
#   'id': 'd43e52c9-f877-7d95-7931-98db5717fded',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:2aa2808b-1642-8600-b168-d872b430518e'}]},
#  {'resource_type': 'Claim', 'id': 'ed354fdc-a3b1-b096-1fd8-f6e0665e99d9'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': 'f133839a-438a-bf15-3b89-96920c65022b',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': 'ed354fdc-a3b1-b096-1fd8-f6e0665e99d9'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '57ae6663-bd77-35a3-f501-3b43afec0203',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '57ae6663-bd77-35a3-f501-3b43afec0203'}]},
#  {'resource_type': 'Condition', 'id': '0f23cee1-a1ab-2ef2-3d52-f25d9dab0710'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '3ee9caf1-0674-ebbb-5620-9770cfe7560f'},
#  {'resource_type': 'DocumentReference',
#   'id': 'fd6e93da-cece-84e1-34e0-058aaeab8391',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:3ee9caf1-0674-ebbb-5620-9770cfe7560f'}]},
#  {'resource_type': 'Claim', 'id': '4b0711c7-c556-1bd6-4e31-89cc46f73500'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': 'e05da274-4dee-2d3e-a892-6b38b63b6de3',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '4b0711c7-c556-1bd6-4e31-89cc46f73500'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'd27a1722-203d-e9d1-3f0f-9bcf51f7ed60',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'd27a1722-203d-e9d1-3f0f-9bcf51f7ed60'}]},
#  {'resource_type': 'Condition', 'id': '80771dcf-8e63-b985-9a49-e6db1d926002'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'ef8889aa-bbaa-4ceb-895e-308822c869bd'},
#  {'resource_type': 'DocumentReference',
#   'id': '9c392ec4-e932-e0d8-5259-9ab937a9cc2e',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:ef8889aa-bbaa-4ceb-895e-308822c869bd'}]},
#  {'resource_type': 'Claim', 'id': 'c2fe4503-988d-9848-e40a-a31828182d26'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '51a9865c-d063-1080-367d-8e6f5c9e4169',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': 'c2fe4503-988d-9848-e40a-a31828182d26'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'a6227c41-cbe0-9372-5d83-b5363d485fb2',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'a6227c41-cbe0-9372-5d83-b5363d485fb2'}]},
#  {'resource_type': 'Condition', 'id': '3862b057-ecca-8c64-ee8a-856c4144bffa'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '8537b46c-f02f-22d2-6a00-4da9ebb1eaf9'},
#  {'resource_type': 'DocumentReference',
#   'id': '700935a9-50ed-1f93-d5d2-2573b7661dec',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:8537b46c-f02f-22d2-6a00-4da9ebb1eaf9'}]},
#  {'resource_type': 'Claim', 'id': 'bb108f01-ffe1-803b-b36f-86d1fee2a699'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': 'ba528ef5-59d0-5cc1-dd75-6d1f5f527b90',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': 'bb108f01-ffe1-803b-b36f-86d1fee2a699'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '8d836471-9d44-0360-98ec-0d1f8da394b2',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '8d836471-9d44-0360-98ec-0d1f8da394b2'}]},
#  {'resource_type': 'Condition', 'id': 'b307e717-50e7-6ec1-911f-7a5777bec7f6'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'd9c6aea0-ab8f-7a59-6ccc-cd9941da2e6a'},
#  {'resource_type': 'DocumentReference',
#   'id': '5baead9f-6478-7910-e4e2-a0dde51e5578',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:d9c6aea0-ab8f-7a59-6ccc-cd9941da2e6a'}]},
#  {'resource_type': 'Claim', 'id': '97004366-8274-1223-89ac-f4571996c06b'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '7bc0f94e-161d-884a-d031-d0c5bdea7e30',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '97004366-8274-1223-89ac-f4571996c06b'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '94915f11-f3e8-cf1c-4805-3b0913e1d760',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '94915f11-f3e8-cf1c-4805-3b0913e1d760'}]},
#  {'resource_type': 'Condition', 'id': 'c99fba9a-d143-12b2-7f30-4cf6258a587d'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '40e97ee2-d241-958b-b730-876e3c1abc7b'},
#  {'resource_type': 'DocumentReference',
#   'id': '6ba8be30-f5c6-08af-10d1-b1ac03cc7b82',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:40e97ee2-d241-958b-b730-876e3c1abc7b'}]},
#  {'resource_type': 'Claim', 'id': '54ea0b8b-a2cd-c216-bdf5-d9de4ef901f2'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '241a7f6f-4513-7549-6d84-4af63324d3a7',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '54ea0b8b-a2cd-c216-bdf5-d9de4ef901f2'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'f724d3b7-af81-5249-eff1-8bc0c4831f7d',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'f724d3b7-af81-5249-eff1-8bc0c4831f7d'}]},
#  {'resource_type': 'Condition', 'id': '65afcae6-4a6b-aeb0-bf5f-bb3714208716'},
#  {'resource_type': 'Observation',
#   'id': '497f5682-b86a-9d16-f677-de15628c1eda'},
#  {'resource_type': 'Observation',
#   'id': 'a21d30df-092b-16b6-7a11-f1a910c1ea3f'},
#  {'resource_type': 'Observation',
#   'id': '5b04ddfe-1bf6-9b50-e4ca-d7eb9b8a584a'},
#  {'resource_type': 'Observation',
#   'id': '5eda47d2-f63a-6b50-ae04-70d57eb68454'},
#  {'resource_type': 'Observation',
#   'id': '26f169ad-6b45-c02e-30bd-74eae5d93f11'},
#  {'resource_type': 'Observation',
#   'id': 'ffe0bef0-0408-a718-9773-e51c7b9923ce'},
#  {'resource_type': 'Observation',
#   'id': 'a13f6908-0613-61cf-521e-23cce7b83df9'},
#  {'resource_type': 'Observation',
#   'id': 'c34b409b-52b0-71ce-f774-0b31d2b202e6'},
#  {'resource_type': 'Observation',
#   'id': 'd04245fc-87f1-b1b0-3c82-94ddcc98a3d0'},
#  {'resource_type': 'Observation',
#   'id': '1bfe24e7-e82b-20d2-ca19-e69cb7e6fc1d'},
#  {'resource_type': 'Observation',
#   'id': '9a17bf6b-86dc-4537-004e-d881588c9fe5'},
#  {'resource_type': 'Procedure', 'id': '74c3f423-aeb3-47ac-5a46-483a27cdceb4'},
#  {'resource_type': 'Procedure', 'id': '3bfa13aa-6163-2e2c-e111-cdab56e94e8f'},
#  {'resource_type': 'Procedure', 'id': '6887b94b-d9b8-d885-88ca-a4b909127335'},
#  {'resource_type': 'Procedure', 'id': '58bcfafe-a0f0-a33a-1890-e064d16dd5a6'},
#  {'resource_type': 'Immunization',
#   'id': 'a7972492-bc08-d4ab-59e2-3b1bbfa37fe8'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '2aff7227-c2eb-3873-4f1d-184d15819108'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '15167de0-0c0a-8d11-8139-8b3bbe569d5f'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'aedc54d5-11b6-a7c9-8b0b-7714ed5b4f16'},
#  {'resource_type': 'DocumentReference',
#   'id': '2310674c-8d34-72cc-b1fe-1c43c7f70aeb',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:aedc54d5-11b6-a7c9-8b0b-7714ed5b4f16'}]},
#  {'resource_type': 'Claim', 'id': '8623c82b-94d5-2996-fa6a-a7029b239d34'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '16cb6fa9-181a-7797-edb0-9333fcf03324',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '8623c82b-94d5-2996-fa6a-a7029b239d34'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'f1677544-05ab-5d15-834f-f9701464244c',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'f1677544-05ab-5d15-834f-f9701464244c'}]},
#  {'resource_type': 'Condition', 'id': 'aa4f74f7-04b7-fe50-e9b3-195e87065064'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '776393ab-24a8-c0e6-7855-b548b456154b'},
#  {'resource_type': 'DocumentReference',
#   'id': '7344d6ed-0cd7-5b79-e8ce-12ecb0cf214c',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:776393ab-24a8-c0e6-7855-b548b456154b'}]},
#  {'resource_type': 'Claim', 'id': 'bb8ec3e0-c0d6-bb8e-2824-b5911be1a5a3'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '92977975-d6b8-e5b8-1325-255a7adcad3f',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': 'bb8ec3e0-c0d6-bb8e-2824-b5911be1a5a3'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '93dab9db-4210-33f5-4023-57dd3e609bc8',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '93dab9db-4210-33f5-4023-57dd3e609bc8'}]},
#  {'resource_type': 'Condition', 'id': '73879731-7a5b-9657-6c56-8df54ccc18e2'},
#  {'resource_type': 'Observation',
#   'id': 'a4efb780-8c63-b9e6-23a3-bad5aa75ebb3'},
#  {'resource_type': 'Observation',
#   'id': 'cc1263ef-7e09-39c4-04be-c86234aa8aa3'},
#  {'resource_type': 'Observation',
#   'id': 'ab6cd72e-a162-3e92-6a2b-4cbaf68c6362'},
#  {'resource_type': 'Observation',
#   'id': 'a3dc7f37-f908-3012-e81a-851943621f2e'},
#  {'resource_type': 'Observation',
#   'id': '1ff72638-7a5c-5d0d-b0ad-a9dbd8ce6756'},
#  {'resource_type': 'Observation',
#   'id': 'e20836c6-c594-bd77-9900-efe3f920edf9'},
#  {'resource_type': 'Observation',
#   'id': '13218f5e-34d0-32d0-cad4-cb1fdaa8bf13'},
#  {'resource_type': 'Observation',
#   'id': 'c5a19909-ed83-eacc-9df0-466560ec1db9'},
#  {'resource_type': 'Observation',
#   'id': 'f577955b-d089-c835-2ab0-847fc82a71a3'},
#  {'resource_type': 'Observation',
#   'id': 'b78a57a2-c731-f610-c1e6-be8d6ed108eb'},
#  {'resource_type': 'Observation',
#   'id': '7f34dd5d-6d38-08fe-0667-5389f3d3b214'},
#  {'resource_type': 'Observation',
#   'id': '180f79e8-8a9e-52e5-2fc1-bd267066724d'},
#  {'resource_type': 'Observation',
#   'id': '12738981-2b78-4ccf-5cc2-7ddf27a5dbf5'},
#  {'resource_type': 'Observation',
#   'id': '0592df67-80d7-3b11-7cdd-5c4ae38fc961'},
#  {'resource_type': 'Observation',
#   'id': 'c1db635e-939a-6faf-7aaf-7fb4a4867fdd'},
#  {'resource_type': 'Observation',
#   'id': '9cf2925c-5216-ceff-0cae-41ead3b47ef1'},
#  {'resource_type': 'Observation',
#   'id': '9d1bd67d-aa9f-7a8b-0d10-ca54e1477fe4'},
#  {'resource_type': 'Observation',
#   'id': 'df97ea3a-6133-c63c-f44f-c648f1dd6985'},
#  {'resource_type': 'Observation',
#   'id': '03babad9-ac34-dbb3-1b77-d29dd2e63c28'},
#  {'resource_type': 'Observation',
#   'id': '3e587e27-9547-affa-aa40-6a7df86a39ef'},
#  {'resource_type': 'Observation',
#   'id': '8601ef65-b6ae-2f5b-81a2-6f8067d3cf4a'},
#  {'resource_type': 'Observation',
#   'id': 'c392e780-6cac-c390-5bc6-9ef58f50ffc0'},
#  {'resource_type': 'Observation',
#   'id': '4b15c483-943f-981c-9ed5-888188585aee'},
#  {'resource_type': 'Observation',
#   'id': 'fa315450-b6b5-40f7-b6b7-d9eed219bdd0'},
#  {'resource_type': 'Observation',
#   'id': '0a7e368e-32fa-a770-fb6f-143d5e63643f'},
#  {'resource_type': 'Observation',
#   'id': 'fa7be9dd-dbbe-614f-539b-fdfccd080eba'},
#  {'resource_type': 'Observation',
#   'id': '66acf851-4b4f-d639-9649-66dedf5b4068'},
#  {'resource_type': 'Observation',
#   'id': '78e4f71d-2d80-d758-b167-1088c324d95d'},
#  {'resource_type': 'Procedure', 'id': 'dd4a4d8d-2b16-8d3a-64c9-d0a892bd911c'},
#  {'resource_type': 'Procedure', 'id': '4e38f738-53c0-dff9-e143-404cd31a155c'},
#  {'resource_type': 'Procedure', 'id': '9152b575-995d-bd9c-51b4-8c7158a2d10e'},
#  {'resource_type': 'Procedure', 'id': 'b3dc640f-8bbf-e2bd-9625-3bd89d129f9f'},
#  {'resource_type': 'Procedure', 'id': 'ea4f6536-4d87-096b-b01f-fe208376f07a'},
#  {'resource_type': 'Procedure', 'id': '5a0158b5-1b11-a251-4924-d811e0101ed0'},
#  {'resource_type': 'Procedure', 'id': '63339267-826e-7c17-a921-4135f079019b'},
#  {'resource_type': 'Procedure', 'id': '90ff03ef-08b6-fd08-88d4-06aca168f7df'},
#  {'resource_type': 'Immunization',
#   'id': 'eaa88d9e-c4a0-d2f4-a40c-0741ead3f532'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'fa34eab8-e9a0-3d57-570e-1cb85560527f'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'e5d2acdd-38e2-55ba-0a5f-c6698d626706'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '9823fac0-4ff8-fa59-adf9-6911ac0a2da6'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '3dd9061c-3e88-3f05-11bc-37e8076f7a5e'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'a0a76ce8-36df-884b-e235-1aee19ed8411'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'dfb9f9c9-7f66-b4d6-6777-2689a106c689'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '277777c6-9669-f911-9d6d-7853f01680bd'},
#  {'resource_type': 'DocumentReference',
#   'id': 'bd368d43-3555-5110-b2ad-8d309ba55356',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:277777c6-9669-f911-9d6d-7853f01680bd'}]},
#  {'resource_type': 'Claim', 'id': '925fd228-261a-acb0-99d0-649fdb8ac36f'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': 'acde9560-ab8c-39fc-e2ea-0553145da59c',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '925fd228-261a-acb0-99d0-649fdb8ac36f'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'cbd4058a-3626-71d2-1c1c-3700f051b52d',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'cbd4058a-3626-71d2-1c1c-3700f051b52d'}]},
#  {'resource_type': 'Condition', 'id': '7e87b0e8-c85b-cac5-2aba-8579dcc0dbb4'},
#  {'resource_type': 'Condition', 'id': '53cb909f-722e-3645-6742-e0faf882ecc3'},
#  {'resource_type': 'Condition', 'id': '38b91319-ba00-cbfd-56cf-6fc2d81ed9fa'},
#  {'resource_type': 'Observation',
#   'id': 'a20fd9cd-524e-477c-09db-64e59c0ca340'},
#  {'resource_type': 'Observation',
#   'id': 'bad61e22-b797-3c17-eb7d-f05fcaef874f'},
#  {'resource_type': 'Observation',
#   'id': 'c865f1af-f9a5-230c-f2db-9c6c1a243876'},
#  {'resource_type': 'Observation',
#   'id': 'ef11cda9-256d-a7ea-13bf-ac15b277199a'},
#  {'resource_type': 'Observation',
#   'id': 'e63e2596-43b3-d730-b054-4f0eb992c77d'},
#  {'resource_type': 'Observation',
#   'id': '4e74f145-523b-1334-f609-bebfaaf77242'},
#  {'resource_type': 'Observation',
#   'id': 'cad36200-cc39-f346-1829-98a0c94fcb30'},
#  {'resource_type': 'Observation',
#   'id': 'b8813704-70f9-7115-7495-09ca23008ab5'},
#  {'resource_type': 'Observation',
#   'id': '15e46528-cf6f-0850-e001-9fc9071bd2ae'},
#  {'resource_type': 'Observation',
#   'id': '873b05e5-6966-ac90-b7f1-d2b59ab1f0e5'},
#  {'resource_type': 'Observation',
#   'id': '4270c177-dabb-b974-56e3-9c84860d45db'},
#  {'resource_type': 'Observation',
#   'id': '57a4285e-976e-410d-2400-b19b75ff53c6'},
#  {'resource_type': 'Procedure', 'id': '4a23b00c-6854-5c7d-8841-2ea2bb4139dc'},
#  {'resource_type': 'Procedure', 'id': '35f146d7-97fd-62da-80aa-cfa1794a1fd2'},
#  {'resource_type': 'Procedure', 'id': 'fb56b337-aa57-2a57-8d64-04462b22559f'},
#  {'resource_type': 'Procedure', 'id': 'bc04322d-d003-b7a5-30f3-75865fe22b85'},
#  {'resource_type': 'Procedure', 'id': 'aed60902-fc4f-ff96-b779-d0674df7c651'},
#  {'resource_type': 'Procedure', 'id': '37f4fe32-70a2-9f04-4c3c-ea1b9c3f73e0'},
#  {'resource_type': 'Immunization',
#   'id': 'c5d0eda6-ac43-acf0-89b8-9151a6ae43e5'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '1fb3ec29-59cd-0aed-4eda-a0c7ba06e8ea'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '3b9fae13-0ea4-d7be-3055-2724b30d2594'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'ee0e254a-62d9-e83e-e04a-b8050a2c4a2a'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'a2498a6a-1ad4-6a80-3e46-3a5450c98657'},
#  {'resource_type': 'DocumentReference',
#   'id': '049f4542-3ecb-1736-deb0-c7df39c3132f',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:a2498a6a-1ad4-6a80-3e46-3a5450c98657'}]},
#  {'resource_type': 'Claim', 'id': '13f46882-200f-9556-010d-72286f29796f'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '5579b4b2-684a-f3fa-786c-007934507808',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '13f46882-200f-9556-010d-72286f29796f'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'fea85666-7ced-5e87-a700-fb3b69294ede',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'fea85666-7ced-5e87-a700-fb3b69294ede'}]},
#  {'resource_type': 'Observation',
#   'id': '668fd3b0-3fa2-6f11-9de2-98873ab071cc'},
#  {'resource_type': 'Observation',
#   'id': '3310dcd4-a5cd-c2fe-c9cf-5dfd3054e7eb'},
#  {'resource_type': 'Observation',
#   'id': 'b827f441-cb29-b5e8-7edc-8bd467dfdb14'},
#  {'resource_type': 'Observation',
#   'id': '4a2621c0-30dc-66c8-ac37-a53184c71ba2'},
#  {'resource_type': 'Observation',
#   'id': 'b6e524e6-58f5-6b50-1807-a9bdf53d9c7c'},
#  {'resource_type': 'Observation',
#   'id': '48e7dacf-1088-d597-9f2f-d471d3012b52'},
#  {'resource_type': 'Observation',
#   'id': '292ecb0c-96c2-6ffb-0e7e-f3b57014e925'},
#  {'resource_type': 'Observation',
#   'id': '64940fdc-9f96-5342-8ff3-aea7f48c470d'},
#  {'resource_type': 'Observation',
#   'id': '77010d9a-9362-3b02-386f-4bbfba828b36'},
#  {'resource_type': 'Observation',
#   'id': 'ed03ad77-a425-3c43-b5b5-cc93fc97222b'},
#  {'resource_type': 'Observation',
#   'id': '42700f68-8329-c262-3b33-72f722074056'},
#  {'resource_type': 'Observation',
#   'id': 'ae16e761-f957-f637-b2ed-03496e0197c7'},
#  {'resource_type': 'Procedure', 'id': '8667f9c4-0f24-f37a-9881-580a0e592634'},
#  {'resource_type': 'Immunization',
#   'id': '8c5b6b13-2175-7062-4378-1aaeb4885f40'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'd873d6eb-6d10-bb8e-5d82-b5b7cb463700'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'bc566233-9cab-3428-be11-d4027f02d0ba'},
#  {'resource_type': 'DocumentReference',
#   'id': '79953c94-7c5d-a047-67f3-0158b8b9d5ef',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:bc566233-9cab-3428-be11-d4027f02d0ba'}]},
#  {'resource_type': 'Claim', 'id': 'b71c4524-82d1-0595-44cf-4050a4e4b99b'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '9976c666-aabc-e831-de9c-a954bc376bba',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': 'b71c4524-82d1-0595-44cf-4050a4e4b99b'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'fa207d77-88d0-13d6-7da2-66ff9576410e',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'fa207d77-88d0-13d6-7da2-66ff9576410e'}]},
#  {'resource_type': 'Condition', 'id': '8e836082-70fa-533c-0bcf-a3ab275c131f'},
#  {'resource_type': 'Observation',
#   'id': 'b366d873-4c8f-b9be-111b-3c45eb73dc83'},
#  {'resource_type': 'Observation',
#   'id': 'ccac61f2-cf24-633c-41ab-4c6b6739555f'},
#  {'resource_type': 'Observation',
#   'id': 'b680c992-7c89-ce42-fae0-e7afa408542d'},
#  {'resource_type': 'Observation',
#   'id': '13e87741-4d45-3469-d155-943bb89af6bf'},
#  {'resource_type': 'Procedure', 'id': '7a007d04-3268-84fd-ec9d-5a9ba452d782'},
#  {'resource_type': 'Procedure', 'id': 'a6b55ce3-ac2d-e5e0-6779-7ed6cd89d307'},
#  {'resource_type': 'Procedure', 'id': '684bba28-a24f-dead-a155-36beaceb21bf'},
#  {'resource_type': 'Procedure', 'id': '582669c7-a016-921f-51a6-f188c89dca06'},
#  {'resource_type': 'Procedure', 'id': '81f8961a-12b4-a9b4-0466-049f9715ae62'},
#  {'resource_type': 'Procedure', 'id': 'e849e9ce-a514-d78d-496d-d1b532f0bc0b'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '2b1df620-eae3-1298-7ca4-ba19bb99fdae'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '74ef484b-3baa-f0f0-634e-734f99c4966d'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '0041e23b-8896-c483-8156-90ddaf6ce92a'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'bc180a87-a1f1-5df4-a8d9-5764512e7005'},
#  {'resource_type': 'DocumentReference',
#   'id': 'bacfa79e-7746-99c3-dbfe-2cef16a10822',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:bc180a87-a1f1-5df4-a8d9-5764512e7005'}]},
#  {'resource_type': 'Claim', 'id': '8c9d9a40-6c1d-1bab-b698-3a8d7158b5af'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '803fcb2e-9605-dc4b-9f37-13242a4f2425',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '8c9d9a40-6c1d-1bab-b698-3a8d7158b5af'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '08d5e025-3564-6d08-6f9a-737e842e66cd',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '08d5e025-3564-6d08-6f9a-737e842e66cd'}]},
#  {'resource_type': 'Condition', 'id': '725bcc06-b31d-1631-e819-6fa8b268bd85'},
#  {'resource_type': 'Condition', 'id': '4e40ae5a-0084-3363-79be-a17d818161c3'},
#  {'resource_type': 'Observation',
#   'id': 'fa47b5f7-26bc-722e-f4e0-2c7da0a69fda'},
#  {'resource_type': 'Observation',
#   'id': 'ac87faf9-c567-d6f8-bf13-aae3a7fdc07c'},
#  {'resource_type': 'Observation',
#   'id': '133b8400-0069-ac21-f8cb-57f62e05867f'},
#  {'resource_type': 'Observation',
#   'id': 'd55cea90-17b5-bf67-a1eb-0b9e797c44e4'},
#  {'resource_type': 'Observation',
#   'id': 'cd1652d9-6d0b-918c-5a78-db3a5882d114'},
#  {'resource_type': 'Observation',
#   'id': '55fbaa9c-c842-5c36-ea76-73afa185d56b'},
#  {'resource_type': 'Observation',
#   'id': '5a35636d-15b5-1215-b72d-80c3e30b47fa'},
#  {'resource_type': 'Observation',
#   'id': '3a601c15-e1ab-bd4a-b60a-b5acd51a0988'},
#  {'resource_type': 'Observation',
#   'id': '3f38ed5b-5991-e007-1ac8-4ae385cdf0da'},
#  {'resource_type': 'Observation',
#   'id': 'f1754de3-669f-bb72-d962-053ecb0ac634'},
#  {'resource_type': 'Observation',
#   'id': 'a6a0c175-6f96-a0ce-595a-1a3dd164f31f'},
#  {'resource_type': 'Observation',
#   'id': '68c9c761-c68e-b0dc-3877-85a5447eea6b'},
#  {'resource_type': 'Observation',
#   'id': '6d6abc40-aed6-ad7e-5c9b-a44a63868c77'},
#  {'resource_type': 'Procedure', 'id': 'dd92a2e1-13cc-c19e-8fd6-282fbd6e0baf'},
#  {'resource_type': 'Procedure', 'id': '391d087b-76a1-634d-84bb-b9d370301555'},
#  {'resource_type': 'Procedure', 'id': '10077826-a463-b42e-0c74-dac4c5274284'},
#  {'resource_type': 'Procedure', 'id': 'cae63191-71c9-0415-f13f-dd794e7d1572'},
#  {'resource_type': 'Procedure', 'id': '5d6116eb-ed17-59ea-d87a-065e2f3506f5'},
#  {'resource_type': 'Procedure', 'id': 'cebd0625-3ab5-26d3-a3f1-2a2eac9c6848'},
#  {'resource_type': 'Procedure', 'id': 'c405115c-145e-8792-7480-5d8945301d0e'},
#  {'resource_type': 'Procedure', 'id': '98aa4a8e-b822-b82b-f50f-89bd4a957196'},
#  {'resource_type': 'Immunization',
#   'id': 'fca81697-f152-9dc9-4e36-fae6e253915f'},
#  {'resource_type': 'Immunization',
#   'id': '9da63b58-e4b3-8ae1-bd45-3b3e9fcf61df'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'a2711d33-e8d7-a197-8676-cfade9e3c580'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'f8b3dfc1-15af-7861-ef14-a9a39b8c8aea'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'db675dba-617e-e4e9-4227-6227d9ba8c87'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'f8242c3a-3f99-1138-16ba-922fc4cbc443'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '11b51d26-54e6-3f10-328c-dc32528a5793'},
#  {'resource_type': 'DocumentReference',
#   'id': '822af4eb-2977-dd98-5cbe-7afa5a41dfb9',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:11b51d26-54e6-3f10-328c-dc32528a5793'}]},
#  {'resource_type': 'Claim', 'id': '15894768-db95-d53e-3ad9-69be4faa7245'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '1b2fb02d-f9fa-2dd8-34ab-796eb75d2dde',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '15894768-db95-d53e-3ad9-69be4faa7245'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '6ea1d9e7-6e9e-730c-3a1b-e751707e4f42',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '6ea1d9e7-6e9e-730c-3a1b-e751707e4f42'}]},
#  {'resource_type': 'Condition', 'id': '7b840912-0bd0-7af2-d6ab-48cd2f85128a'},
#  {'resource_type': 'Observation',
#   'id': 'bbc91df8-007a-72f7-09e5-e08525c9e4b2'},
#  {'resource_type': 'Observation',
#   'id': 'ed6a41d9-80e4-5704-fffd-b0a8c507a959'},
#  {'resource_type': 'Observation',
#   'id': 'bdcfb369-fcf3-36de-b342-de87cd8518c4'},
#  {'resource_type': 'Observation',
#   'id': '1f95667b-9e4c-edcf-3b86-3b689d677a28'},
#  {'resource_type': 'Observation',
#   'id': '12cd6afc-b60d-3086-b4db-069bc8003e28'},
#  {'resource_type': 'Observation',
#   'id': 'b38d4f22-9523-153b-20ea-3ccad8fb3d9c'},
#  {'resource_type': 'Observation',
#   'id': 'b5b2f0e5-c23c-7a16-f65b-0895596ba093'},
#  {'resource_type': 'Observation',
#   'id': '92a072ad-fe96-edd1-8df9-285c8011b19b'},
#  {'resource_type': 'Observation',
#   'id': '0d76474d-5663-fe9b-ae7b-5d5dbb14213f'},
#  {'resource_type': 'Observation',
#   'id': 'ff4d892d-fbe9-133f-db59-38018c0b7dd0'},
#  {'resource_type': 'Observation',
#   'id': 'b66410ce-b461-3285-1240-d57417e6e368'},
#  {'resource_type': 'Observation',
#   'id': '6c4efe6b-9d29-5cd8-72b2-6272af1d282b'},
#  {'resource_type': 'Observation',
#   'id': '375faafc-5d26-5c28-1d50-7769500e08d0'},
#  {'resource_type': 'Observation',
#   'id': '5db2345f-ebdd-2e11-f9d1-a1bb61ab195f'},
#  {'resource_type': 'Observation',
#   'id': '841c18d9-d3a5-6c3d-2470-ae6247b87e3b'},
#  {'resource_type': 'Observation',
#   'id': 'fba495ba-b8ef-5706-7b7e-89b9e871b163'},
#  {'resource_type': 'Observation',
#   'id': '8497bd60-640d-665e-2c91-c89a355ed7f4'},
#  {'resource_type': 'Observation',
#   'id': '89e0785e-178b-84f2-93fd-2ea47aeb6bf2'},
#  {'resource_type': 'Observation',
#   'id': 'd964e5fb-911c-598d-31f7-c5dcdc173e47'},
#  {'resource_type': 'Observation',
#   'id': 'a9e3cfe1-40c7-42ba-ac76-5b7f6da7150a'},
#  {'resource_type': 'Observation',
#   'id': 'bb89250e-7f87-e8ad-a45f-760ddeca6a05'},
#  {'resource_type': 'Observation',
#   'id': '295ab00d-763a-8963-bdc0-18a848800d71'},
#  {'resource_type': 'Procedure', 'id': '25fd7c69-f5be-6308-5e38-e7a1615bb103'},
#  {'resource_type': 'Procedure', 'id': '21679f62-5be9-e098-e840-824efcea9f2b'},
#  {'resource_type': 'Procedure', 'id': '6e1957da-4c82-6cc7-4651-2620fd16229a'},
#  {'resource_type': 'Procedure', 'id': '56b3b992-2c24-0f25-6be4-eef604c66205'},
#  {'resource_type': 'Immunization',
#   'id': '0f725799-fb23-377d-9c85-48aaa5f0b429'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '1d70a204-1a35-5b7e-3067-65f60e68b00e'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'b6faeada-4053-4a9d-ab58-d0717e7b7d8e'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '7fb64652-3312-5c39-1b5c-65f8fed12a18'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '8869ba3f-c6df-dbff-3989-5738c08805b1'},
#  {'resource_type': 'DocumentReference',
#   'id': '07e670cb-0d5c-588f-e6c2-fb817f3a4c3c',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:8869ba3f-c6df-dbff-3989-5738c08805b1'}]},
#  {'resource_type': 'Claim', 'id': '3033e263-0bca-b85f-9ff9-8ddbd0de9efa'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '5c002af1-a461-38e0-0811-275fff781253',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '3033e263-0bca-b85f-9ff9-8ddbd0de9efa'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '93a3fe50-b988-bbde-d98d-8ac74c92d3d6',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '93a3fe50-b988-bbde-d98d-8ac74c92d3d6'}]},
#  {'resource_type': 'Condition', 'id': 'ca0ceffc-cbf9-072c-7cf6-953e12d6ac7d'},
#  {'resource_type': 'Observation',
#   'id': 'd7d8020a-2266-da7f-3bd2-687d5ec8e335'},
#  {'resource_type': 'Observation',
#   'id': '0111af56-c562-ff9a-004f-a217516b439e'},
#  {'resource_type': 'Observation',
#   'id': '07afe501-8257-b8ab-c88b-3411f5fe4d0f'},
#  {'resource_type': 'Observation',
#   'id': '752d9f1d-9f84-30f4-3f02-b2ba7408cddc'},
#  {'resource_type': 'Observation',
#   'id': 'd7f71ca2-b6ab-d3ae-317d-2bb180276eda'},
#  {'resource_type': 'Observation',
#   'id': '58d0dea5-3729-ad29-21c1-da4b354af323'},
#  {'resource_type': 'Observation',
#   'id': 'e852e6c8-a876-3a37-b915-4d17ad343016'},
#  {'resource_type': 'Observation',
#   'id': 'a834e8f2-de30-49cb-25ea-d0c09e6901a1'},
#  {'resource_type': 'Observation',
#   'id': '66bf6443-bc9f-d4dc-13c1-341757cdbec2'},
#  {'resource_type': 'Observation',
#   'id': '7f80d742-eab3-f08f-0cff-3968cac2f24a'},
#  {'resource_type': 'Observation',
#   'id': '2aa58359-3aeb-3e94-4f15-49151c5f5be3'},
#  {'resource_type': 'Observation',
#   'id': 'd7437381-b1a8-7fcf-df6f-3960d95a7d55'},
#  {'resource_type': 'Observation',
#   'id': '33d3ba40-c36b-2d3b-8d1a-3f8b56bc3804'},
#  {'resource_type': 'Observation',
#   'id': 'ce2d1ad3-ba7e-3b0b-5cb0-5e1db7aa3ebc'},
#  {'resource_type': 'Observation',
#   'id': 'f8e391a8-982d-6a11-135b-e48636f45fb1'},
#  {'resource_type': 'Observation',
#   'id': 'da337010-4bb3-cb63-77da-d3e5ad8ceac0'},
#  {'resource_type': 'Observation',
#   'id': '17d5ff30-b71c-5a3b-c693-3d295e2ab7fb'},
#  {'resource_type': 'Observation',
#   'id': '9688de3e-ca77-d01f-6d46-ec5716269264'},
#  {'resource_type': 'Observation',
#   'id': 'caf08fed-7e59-1741-ad05-f528fc7e0af7'},
#  {'resource_type': 'Observation',
#   'id': '6711eb20-c9bb-ff28-52e4-f4de7e01f7ed'},
#  {'resource_type': 'Observation',
#   'id': 'fb2562e6-db90-178e-7af5-1d4eb957243f'},
#  {'resource_type': 'Observation',
#   'id': 'd54259a8-0f5b-d58c-c249-5d4172d3f368'},
#  {'resource_type': 'Observation',
#   'id': 'e88ff399-d50a-66f4-7db5-39f9c7adfd6f'},
#  {'resource_type': 'Observation',
#   'id': '5d8c1c7a-4838-d7fd-60a7-2e15ad96e724'},
#  {'resource_type': 'Observation',
#   'id': '28d0b478-917d-6f25-7349-a19a6817faa9'},
#  {'resource_type': 'Observation',
#   'id': '5fca1872-9e6e-6353-9632-cf48e3f04433'},
#  {'resource_type': 'Observation',
#   'id': '2a517965-e1db-503b-fd9d-2b35c2b13712'},
#  {'resource_type': 'Observation',
#   'id': '0850b720-e6ff-0d06-bba7-1e9a7a121eee'},
#  {'resource_type': 'Observation',
#   'id': '82bcb23a-b6a5-c931-69b2-2ce77332e152'},
#  {'resource_type': 'Observation',
#   'id': '528e4945-a69d-93b4-61e6-d61b828ad36e'},
#  {'resource_type': 'Observation',
#   'id': '0e317544-d885-b067-7463-ca5b59c8a818'},
#  {'resource_type': 'Observation',
#   'id': 'b9653959-bf73-5fa1-1cf4-42b7f5b4ba14'},
#  {'resource_type': 'Observation',
#   'id': '4bfe59c2-b228-fc22-8f92-935343773694'},
#  {'resource_type': 'Observation',
#   'id': 'c4aa0e07-3406-9332-68b9-4aa7ceb7ec01'},
#  {'resource_type': 'Observation',
#   'id': '74ed226a-f7a9-5b09-ebd6-7224c525c0fb'},
#  {'resource_type': 'Observation',
#   'id': '666f3cab-0da1-ab71-d359-c3fbc850179e'},
#  {'resource_type': 'Observation',
#   'id': '7e6937e6-7dfd-5ca9-340f-ea3a349ca107'},
#  {'resource_type': 'Observation',
#   'id': '0608cbd9-1ede-b08c-960a-1b17c7c86516'},
#  {'resource_type': 'Observation',
#   'id': '9d0af34f-a336-29f2-7972-a691030b0274'},
#  {'resource_type': 'Observation',
#   'id': '29f1c5d8-0d37-f656-2aa4-4933a0df6ad7'},
#  {'resource_type': 'Observation',
#   'id': 'e051b8b9-3e8b-cdb9-47e3-583adce59f84'},
#  {'resource_type': 'Observation',
#   'id': 'ecfd7b21-c6c0-6cc5-3975-1adac1853215'},
#  {'resource_type': 'Observation',
#   'id': '3096e1a6-2d7a-0d34-3bc2-e4dcdb308d7c'},
#  {'resource_type': 'Observation',
#   'id': 'ce7e94e7-4b65-8072-6ffb-c66c80a54b47'},
#  {'resource_type': 'Observation',
#   'id': '4f837790-396f-d081-bb80-e530c2861925'},
#  {'resource_type': 'Procedure', 'id': 'f84df788-7b5c-8b1c-6e95-d29d3f6ef2a8'},
#  {'resource_type': 'Procedure', 'id': '7a92be63-3fd3-1b1f-a88f-7384c46cb34c'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'c8db751c-6e9d-d425-0051-4cf348cd44b7'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'f66b8f01-3c5b-9472-f492-4a3a77cded42'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '4ab24fed-b38f-2113-3d5f-504a5f0182b7'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '191a81bd-1405-a043-08e3-3245c5a0855c'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '461b8cfb-b53f-d611-0de0-db5333916730'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '6076e8e0-c520-073e-d7c5-c1b357178374'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'c4c8167a-73d8-a66b-c007-f71099fb8a6c'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'c13c9b27-ef36-2f73-3fe4-6a1caae86566'},
#  {'resource_type': 'DocumentReference',
#   'id': '32acae4c-ac20-d515-09c7-2d5b21e3d6fb',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:c13c9b27-ef36-2f73-3fe4-6a1caae86566'}]},
#  {'resource_type': 'Claim', 'id': 'a2a48e44-7bd8-e4d6-23f0-d738577a5b94'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': 'c279b090-853b-0525-db89-4f5de9aa0e2f',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': 'a2a48e44-7bd8-e4d6-23f0-d738577a5b94'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'e9864158-8f87-b1bf-3981-9d4828109563',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'e9864158-8f87-b1bf-3981-9d4828109563'}]},
#  {'resource_type': 'Observation',
#   'id': '5f58a613-ddfb-9a55-deab-8c17e69c5ca1'},
#  {'resource_type': 'Observation',
#   'id': '0d4bf77f-d03c-c76b-1b87-37a7b3419dbc'},
#  {'resource_type': 'Observation',
#   'id': '40d9a6d8-5d7a-a982-57b3-d6dd9437feaa'},
#  {'resource_type': 'Observation',
#   'id': '7043c245-7d5d-7679-9df2-5743c14dc78c'},
#  {'resource_type': 'Observation',
#   'id': '293a8c95-7cc3-792f-697d-9dd6f829f4eb'},
#  {'resource_type': 'Observation',
#   'id': '1c175c29-cb11-376d-b965-811e5926aa44'},
#  {'resource_type': 'Observation',
#   'id': '7171f533-d9c3-9203-63d6-d07e2d01c8c6'},
#  {'resource_type': 'Observation',
#   'id': '9274d322-7141-4330-a70b-fccb9339ae59'},
#  {'resource_type': 'Observation',
#   'id': '49a81555-45db-5f46-dd47-362331c860e2'},
#  {'resource_type': 'Procedure', 'id': '99320316-64c2-bb8e-edf0-12f8614fa9c5'},
#  {'resource_type': 'Procedure', 'id': '00075aca-2cb2-5f68-d4fc-146a90ece5ab'},
#  {'resource_type': 'MedicationRequest',
#   'id': 'c874e064-3f6d-63b7-346a-9bdf53138c84'},
#  {'resource_type': 'Claim', 'id': 'b30edf1a-2230-e47b-ff12-25cb8d39b5cf'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '28aa9259-f220-e8be-a185-ddd2ff121d18'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '8fd0a9fe-a0c1-64b4-aab7-e011e7c36ac2'},
#  {'resource_type': 'CareTeam', 'id': '5d575dbe-f9fa-ba1d-7b6d-bbb92044c506'},
#  {'resource_type': 'CarePlan', 'id': '9fc5c3e8-433b-5aee-66e2-0adcfe03ed3b'},
#  {'resource_type': 'ImagingStudy',
#   'id': 'b1095f4b-783e-722f-7947-338ba8796d57',
#   'identifier': [{'use': 'official',
#     'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:oid:1.2.840.99999999.51631375.870143405291'}]},
#  {'resource_type': 'DiagnosticReport',
#   'id': '35221878-1019-b726-a78c-a61ff39399b5'},
#  {'resource_type': 'DocumentReference',
#   'id': 'd5f8162b-3ab2-ceb5-f009-2cd800296b18',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:35221878-1019-b726-a78c-a61ff39399b5'}]},
#  {'resource_type': 'Claim', 'id': '37d22904-bdde-df00-32c2-20a3d73274ef'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '561abe7d-f875-3952-9b30-973f6c917bda',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '37d22904-bdde-df00-32c2-20a3d73274ef'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'f08c8f1a-32c8-3e41-09e2-de833713706c',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'f08c8f1a-32c8-3e41-09e2-de833713706c'}]},
#  {'resource_type': 'Condition', 'id': '7cbf7bd9-c585-e00f-4369-d8f81d1cd232'},
#  {'resource_type': 'Observation',
#   'id': '72a14ef4-e433-6753-d8e7-0fad649bbef4'},
#  {'resource_type': 'Observation',
#   'id': 'faed53c7-058e-5dd7-ee89-8d4ab175323a'},
#  {'resource_type': 'Observation',
#   'id': '7070fa09-2456-c3c4-b294-d665bc083911'},
#  {'resource_type': 'Observation',
#   'id': 'a71af841-f4a4-f2fc-956e-931621ca1e0e'},
#  {'resource_type': 'Observation',
#   'id': '19b5a17c-df2f-d4c7-05e4-bdc5a0aad193'},
#  {'resource_type': 'Observation',
#   'id': '8004623c-330e-4db0-95a7-6b4ad3211250'},
#  {'resource_type': 'Observation',
#   'id': '9e0798ab-c1c9-03b1-460e-803782b21a0d'},
#  {'resource_type': 'Observation',
#   'id': '89a93c18-9f3f-e28d-35f4-e76f49c0d2a5'},
#  {'resource_type': 'Observation',
#   'id': '114807a3-4939-027d-b3f8-1dfb2facd755'},
#  {'resource_type': 'Observation',
#   'id': '32be1c32-2fa4-d50e-9e04-281d5c09c636'},
#  {'resource_type': 'Observation',
#   'id': 'badb4da6-c0fd-bc49-1501-43a3e33ba608'},
#  {'resource_type': 'Observation',
#   'id': 'b01a8f53-6be7-7014-92f9-eb81004d6430'},
#  {'resource_type': 'Observation',
#   'id': '4bdd33ab-ca94-d5d7-e865-009a09a2af03'},
#  {'resource_type': 'Observation',
#   'id': '22edf33c-9bc1-2e61-23a9-2bddd076b044'},
#  {'resource_type': 'Procedure', 'id': '13b8eedd-a273-be0d-d9ab-cd996a2d6beb'},
#  {'resource_type': 'Procedure', 'id': '6dc52124-bf93-5320-308f-0e092695c728'},
#  {'resource_type': 'Procedure', 'id': '0dcef31b-f8c1-4e75-c3e7-e3307b967ba6'},
#  {'resource_type': 'MedicationRequest',
#   'id': '53aae832-ed4a-125b-64ee-1feb45a07b13'},
#  {'resource_type': 'Claim', 'id': '8e129577-de72-fbbd-96b5-e042f8e586e0'},
#  {'resource_type': 'Immunization',
#   'id': 'dbed5804-ba4c-4984-c7a2-e70259fa0045'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '65c97eb7-f9af-9638-d33b-c08969753487'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'fc51db28-f179-c7ed-838b-bee03d93a97d'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '94d6edd7-ee99-9a5c-24a0-230e33132e50'},
#  {'resource_type': 'DocumentReference',
#   'id': '3ac221a5-f27a-274f-e89e-07aad3b8b481',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:94d6edd7-ee99-9a5c-24a0-230e33132e50'}]},
#  {'resource_type': 'Claim', 'id': 'ff3cca85-abe3-1142-ccb3-e0b2f96c3530'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '4ebbdb73-bdde-3447-f002-a49b80d7269a',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': 'ff3cca85-abe3-1142-ccb3-e0b2f96c3530'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '29bc87a5-14cd-012a-3ac7-f2a8823645e3',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '29bc87a5-14cd-012a-3ac7-f2a8823645e3'}]},
#  {'resource_type': 'Observation',
#   'id': 'ca0d42fe-dfd5-e6d4-bed3-ca7fbad7b915'},
#  {'resource_type': 'Observation',
#   'id': 'b3c1d5cb-5474-6df4-27e9-a8fa11cacd68'},
#  {'resource_type': 'Observation',
#   'id': '77a877a8-217c-eadb-bc56-1e39eed6d5c3'},
#  {'resource_type': 'Observation',
#   'id': '200125c2-008e-e9a7-00ff-31003822ed82'},
#  {'resource_type': 'Observation',
#   'id': '6e97a844-26ff-b8a3-d1c7-233f0150a379'},
#  {'resource_type': 'Observation',
#   'id': '8073fb0a-13f8-b4ee-3c7e-6bec5267d139'},
#  {'resource_type': 'Observation',
#   'id': 'ce5c0d9a-e71b-3d59-531a-fa187e122291'},
#  {'resource_type': 'Observation',
#   'id': 'c59d0e55-b3b6-6f95-76b8-153f99891157'},
#  {'resource_type': 'Observation',
#   'id': 'b941b4ea-36b9-138e-e143-6ee325815968'},
#  {'resource_type': 'Observation',
#   'id': 'c43e400a-a34c-5911-d4f1-3955728b28ec'},
#  {'resource_type': 'Observation',
#   'id': '68721a62-79aa-4bb4-4fda-57d2e50e90de'},
#  {'resource_type': 'Observation',
#   'id': '7fea5ac4-478d-20f6-3cc4-fbd5d97ff9cb'},
#  {'resource_type': 'Observation',
#   'id': '24cf93a5-e7c2-c4a4-3949-43ac70e0a0d9'},
#  {'resource_type': 'Observation',
#   'id': 'ec1ca5d0-1942-477e-6288-ae432c5b610a'},
#  {'resource_type': 'Observation',
#   'id': '86e38a50-bbd7-141a-75c8-7847a50e4cc2'},
#  {'resource_type': 'Observation',
#   'id': '20c047b2-7350-0e09-8eac-36704f15db86'},
#  {'resource_type': 'Observation',
#   'id': '9f69866e-105e-ff37-1acf-41138cf6b006'},
#  {'resource_type': 'Observation',
#   'id': 'f251789f-ba36-f797-3f50-c5031ecf3a5c'},
#  {'resource_type': 'Observation',
#   'id': '914108fe-23be-82ff-01cf-8d936f8aba96'},
#  {'resource_type': 'Observation',
#   'id': 'f9028504-f514-d950-788f-dbf96de36771'},
#  {'resource_type': 'Observation',
#   'id': 'b4d03676-3c77-6cd9-1656-dfd98799bd67'},
#  {'resource_type': 'Observation',
#   'id': '558ea000-1287-7afc-ab2c-a5214f2339ec'},
#  {'resource_type': 'Observation',
#   'id': '9421513e-6bc5-8312-d4ee-8b121f7306f3'},
#  {'resource_type': 'Observation',
#   'id': 'eda485e3-3e12-c78b-96a9-989f4aa35ab7'},
#  {'resource_type': 'Observation',
#   'id': 'ee450432-fb67-3d5a-7555-41f99f6e8fb7'},
#  {'resource_type': 'Observation',
#   'id': '6d12eeb3-dcec-8d8f-70fc-736b32d33901'},
#  {'resource_type': 'Observation',
#   'id': '77c37d25-6995-0d45-33eb-f562bf2eb6b3'},
#  {'resource_type': 'Observation',
#   'id': '1420d0af-034f-cfbd-eb5a-7dcfb4ce0ebe'},
#  {'resource_type': 'Observation',
#   'id': '3d26575a-7469-36cb-0f70-02b271ad0ded'},
#  {'resource_type': 'Observation',
#   'id': '3ebb72c2-75b9-a570-60d7-21ed6b17f525'},
#  {'resource_type': 'Observation',
#   'id': '63e55608-dc3a-38c8-195c-b261546436ee'},
#  {'resource_type': 'Observation',
#   'id': '9b644f0e-93b1-ab26-98ce-d2372e390931'},
#  {'resource_type': 'Observation',
#   'id': '853feee0-32a9-c57d-288e-067d6228cf43'},
#  {'resource_type': 'Observation',
#   'id': '3c08c56d-dc00-0301-0c58-3ff49ae8a021'},
#  {'resource_type': 'Observation',
#   'id': '05cda47f-426a-4b0d-56fe-d9296a836cfd'},
#  {'resource_type': 'Observation',
#   'id': '062d9de8-1472-e546-8b35-e1c349ba8bf9'},
#  {'resource_type': 'Observation',
#   'id': '9bcf30fb-59fd-0c01-34bc-4b1b569dab31'},
#  {'resource_type': 'Observation',
#   'id': '8b185b3c-8195-c0e1-7201-ca1000806fff'},
#  {'resource_type': 'Procedure', 'id': 'ad8a805c-09ea-c7c4-0368-821995144679'},
#  {'resource_type': 'Procedure', 'id': 'fbe05d5f-04fb-ebe0-608d-cd9f39d1253e'},
#  {'resource_type': 'Procedure', 'id': '503b7b1d-b538-f328-9ee6-b7861e404972'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'c091d3f5-6b00-e3f4-84b1-fa09bb682f06'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '7763a0b3-a91d-80e0-f10a-96d062c9493c'},
#  {'resource_type': 'DiagnosticReport',
# ...
#  {'resource_type': 'Observation',
#   'id': '98c4390c-4121-a1b2-2712-d6db04699053'},
#  {'resource_type': 'Observation',
#   'id': '179478b5-8d26-f71b-577c-5ec99741f5a1'},
#  {'resource_type': 'Observation',
#   'id': 'cd71c3cd-eaff-ccae-e76a-9ad048d1dfa2'},
#  {'resource_type': 'Observation',
#   'id': 'eab941ed-14c7-2026-0872-3f94c6223f1c'},
#  {'resource_type': 'Observation',
#   'id': '3d372f03-4318-fbe8-cf3a-c20e4d00b388'},
#  {'resource_type': 'Observation',
#   'id': '0d63818b-2d27-f31f-335c-8aca6928ddd1'},
#  {'resource_type': 'Observation',
#   'id': '0e063fff-156b-bc27-609e-8a8b2f699b5b'},
#  {'resource_type': 'Observation',
#   'id': 'ddc7398c-71b4-8d2e-4ba0-0417fcb46d46'},
#  {'resource_type': 'Observation',
#   'id': '62341609-6c05-1f18-cf74-9f5139258ff3'},
#  {'resource_type': 'Observation',
#   'id': '3d02f124-d34f-7aa3-2386-1983b2f786c6'},
#  {'resource_type': 'Observation',
#   'id': '2606f4e0-264e-f3cc-ca70-26fe2b3d202d'},
#  {'resource_type': 'Observation',
#   'id': '21afa73b-e17b-f770-98c0-59e3426935e1'},
#  {'resource_type': 'Observation',
#   'id': '6442df32-b9bc-8f35-96cd-2241355bad6b'},
#  {'resource_type': 'Observation',
#   'id': '708c94ea-aa3e-bfaa-1874-3b62b11f7cea'},
#  {'resource_type': 'Observation',
#   'id': '54bf0127-d318-24ac-d1c2-1a6353fdb813'},
#  {'resource_type': 'Observation',
#   'id': '34f0c000-da18-700c-2589-32026a45e978'},
#  {'resource_type': 'Observation',
#   'id': 'ef4dead6-75f2-ae6e-b409-1fbac46c3c0c'},
#  {'resource_type': 'Observation',
#   'id': '1dec5d7f-cfbb-7673-e933-16149f2238e5'},
#  {'resource_type': 'Observation',
#   'id': '0c829ac9-a5f8-661a-251a-1838f5171d44'},
#  {'resource_type': 'Observation',
#   'id': '18440420-695f-9263-1af2-dac2f1590cd2'},
#  {'resource_type': 'Observation',
#   'id': '051c5885-9c2b-cd35-44f0-5ddbd920a42c'},
#  {'resource_type': 'Observation',
#   'id': 'f8afaecb-6bd4-e580-3a87-9487a864afa1'},
#  {'resource_type': 'Observation',
#   'id': '50235efd-0849-45a6-5475-ad3bce2c0a3a'},
#  {'resource_type': 'Observation',
#   'id': '6d078f1e-85b8-9416-2b89-cfb3406fe8fa'},
#  {'resource_type': 'Observation',
#   'id': 'd7005718-e4d5-3a3a-0dec-640153c11666'},
#  {'resource_type': 'Observation',
#   'id': 'd648afef-1b6c-f593-bfab-36e6f506e246'},
#  {'resource_type': 'Observation',
#   'id': '9618a235-f296-d721-8ff3-0f68abd6c9ad'},
#  {'resource_type': 'Observation',
#   'id': '409b67c2-3ab7-5507-a1d4-899e06501b37'},
#  {'resource_type': 'Observation',
#   'id': 'a7b974a4-0681-526f-f6fb-4ac61c571b92'},
#  {'resource_type': 'Procedure', 'id': '69c59b53-4f25-41ab-619b-e2a0dbbf6e3e'},
#  {'resource_type': 'Procedure', 'id': '065bc027-f34d-c49c-a24d-edfdf1adc698'},
#  {'resource_type': 'Procedure', 'id': 'a9b2d00f-729b-6f57-13cd-4e90d3752514'},
#  {'resource_type': 'Procedure', 'id': '2a8aee7a-fe47-9104-eaf6-8c0992b424c9'},
#  {'resource_type': 'Procedure', 'id': '9bfc0e9a-7fb0-2709-19ff-b26181bb1d32'},
#  {'resource_type': 'Medication', 'id': '27f86bca-7d0d-5e68-c430-4176ee8c1c32'},
#  {'resource_type': 'MedicationRequest',
#   'id': '9c99954a-5db3-4765-2870-01da6051fc58'},
#  {'resource_type': 'Claim', 'id': '14860134-7048-9f6c-562d-d2e84d3c1b64'},
#  {'resource_type': 'MedicationAdministration',
#   'id': '85285aaa-5885-d530-8e9c-c6177180750a'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '5350ff4e-ad9d-ab17-2557-1b91141e25f5'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '9b6d5ff8-b8a3-1bd4-1c5b-f40627169b0e'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'd50838a4-7156-6555-c155-cbbe5f73f0fd'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '4d00d3a9-39fd-5de0-ba65-12ecf1d747ef'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '7e16cc2d-fe89-7778-488b-774a6ab20f99'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '274b03e0-7290-1585-f289-b2e239f98f7d'},
#  {'resource_type': 'CareTeam', 'id': 'aa6dbfdf-4ac0-18b3-45ca-f427a1542f6c'},
#  {'resource_type': 'CarePlan', 'id': '763d20f9-b3c9-c51a-3116-335125b4444b'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '35f66b1b-905c-669e-8f6f-08ddda4c6519'},
#  {'resource_type': 'DocumentReference',
#   'id': '176fd005-742f-5798-7e14-d9797f058c30',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:35f66b1b-905c-669e-8f6f-08ddda4c6519'}]},
#  {'resource_type': 'Claim', 'id': '87f7b13c-0942-4db5-d828-6b04b05f88ca'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '5a918d42-d8db-111e-ca6d-36f03e2884c7',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '87f7b13c-0942-4db5-d828-6b04b05f88ca'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': 'def80c0c-0185-01d9-931d-0dca2200a2ac',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': 'def80c0c-0185-01d9-931d-0dca2200a2ac'}]},
#  {'resource_type': 'Observation',
#   'id': '3b4edeab-88b9-0f6e-b219-e01aba6af7ee'},
#  {'resource_type': 'Observation',
#   'id': '81e6664d-e81b-06cd-a632-c06fa37d6771'},
#  {'resource_type': 'Observation',
#   'id': 'dc1e5668-8da3-5a6e-c1ee-72b74755204a'},
#  {'resource_type': 'Observation',
#   'id': '8a93c635-01da-c8ba-269f-1ccb968dc4cc'},
#  {'resource_type': 'Observation',
#   'id': 'ec9a6559-a9bf-84a9-e4a7-ec5310557dc2'},
#  {'resource_type': 'Observation',
#   'id': 'b4c7c7e9-e941-c4ab-0516-c5c7aa987df8'},
#  {'resource_type': 'Observation',
#   'id': '9152fd91-31bf-dbcc-9841-50d35962ba00'},
#  {'resource_type': 'Observation',
#   'id': 'fc79e80b-13c8-4112-2035-f5e0013ed832'},
#  {'resource_type': 'Observation',
#   'id': '764104d5-2eea-2929-f1c6-a0eee7459cf4'},
#  {'resource_type': 'Observation',
#   'id': 'dcf99e27-2bc3-9641-acfc-5da81301573a'},
#  {'resource_type': 'Observation',
#   'id': 'f0459720-4606-0237-4320-20b1367d1150'},
#  {'resource_type': 'Observation',
#   'id': 'b20f4743-2c19-06f2-4676-5244380f89d7'},
#  {'resource_type': 'Observation',
#   'id': '755f1920-a294-a90f-6b8f-edfb53ee390c'},
#  {'resource_type': 'Observation',
#   'id': '135fe057-d143-28c0-3eed-4bee6994e650'},
#  {'resource_type': 'Observation',
#   'id': '3e7e1aba-eff4-7cf1-78db-e6fe9ed291e3'},
#  {'resource_type': 'Observation',
#   'id': '019d90d2-216b-dcac-fe39-b4734814b6f3'},
#  {'resource_type': 'Observation',
#   'id': '99240984-3c51-fabd-445d-e0c5779629d5'},
#  {'resource_type': 'Observation',
#   'id': '644f0511-839c-d798-5210-05b5b3a71691'},
#  {'resource_type': 'Observation',
#   'id': '4a35b347-7b88-4d7b-2474-2da7e397e3a4'},
#  {'resource_type': 'Observation',
#   'id': 'a63798ed-1c48-bacf-9663-382c4b28fd00'},
#  {'resource_type': 'Observation',
#   'id': '66ab9883-4253-6ed3-a00c-73d979fdcb57'},
#  {'resource_type': 'Observation',
#   'id': '35aa522b-ebae-bc7b-8536-815ef7b15b98'},
#  {'resource_type': 'Observation',
#   'id': '320a0ee9-3c75-d795-4f42-d3da820f7ab9'},
#  {'resource_type': 'Observation',
#   'id': '4d51ab0a-78da-e02e-4e78-626c41dd49b7'},
#  {'resource_type': 'Observation',
#   'id': 'e5cb33e0-d2b3-c033-b94f-5f0507c88dda'},
#  {'resource_type': 'Observation',
#   'id': 'b1362cb8-aa44-bf5a-51c1-06838ec5413d'},
#  {'resource_type': 'Observation',
#   'id': 'c024af06-6fc5-f142-0d3b-de02cf95278d'},
#  {'resource_type': 'Observation',
#   'id': 'fb0dd9dc-cb4e-e1d9-750d-f16d8aad6b10'},
#  {'resource_type': 'Observation',
#   'id': '5bd344a4-d5a6-23fd-081b-e7567e6a85e9'},
#  {'resource_type': 'Observation',
#   'id': 'a81e690e-a428-a665-9cd4-fe02f7c2fb99'},
#  {'resource_type': 'Observation',
#   'id': '1dd63842-fed6-f2c2-38c1-45ceffada6c9'},
#  {'resource_type': 'Observation',
#   'id': '5a3c4f5a-f7d4-bb21-3b08-acb0cf789f46'},
#  {'resource_type': 'Observation',
#   'id': '79447f14-1989-5992-1626-af182e99fc4c'},
#  {'resource_type': 'Observation',
#   'id': 'a4b09ac1-b256-260e-43e7-c1f92553f706'},
#  {'resource_type': 'Observation',
#   'id': 'e4a5c284-44c1-c695-0b0a-ca2b0d1a3155'},
#  {'resource_type': 'Observation',
#   'id': '4d0f9cb8-8f45-dd97-18b2-34f1823e24d0'},
#  {'resource_type': 'Observation',
#   'id': '9f7932b1-d9de-ba94-ae75-85d85e44fe0b'},
#  {'resource_type': 'Observation',
#   'id': '1f4a64a8-0752-f106-219d-6dc37fa9681c'},
#  {'resource_type': 'Procedure', 'id': 'd1d428f0-3722-f97e-de21-bf444ef00c5a'},
#  {'resource_type': 'Procedure', 'id': '53850a6c-e16f-410c-e1a1-d42c421dca68'},
#  {'resource_type': 'Procedure', 'id': '23429a45-3225-4ae3-5505-3864f30aec71'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '0b7bc8d5-daaa-c83d-47fb-adfe12fedbb4'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'a15359ea-9347-ca7c-a570-de86c2b41943'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '9c80e82a-75ff-7391-e479-4d9dc19c7f06'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'b17a2bd1-3d98-c8a1-3383-60c8ee3a0d06'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '325d78a1-2b8f-8ae5-6cf0-9085a3e0c6e8'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'd531a718-f0bf-3ad1-e9e8-16a1547a65b6'},
#  {'resource_type': 'ImagingStudy',
#   'id': 'd69edce6-dd18-a978-b375-adc4072ce1e5',
#   'identifier': [{'use': 'official',
#     'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:oid:1.2.840.99999999.21462423.901337233291'}]},
#  {'resource_type': 'DiagnosticReport',
#   'id': '3a86e89a-e4d4-bc2e-e81c-365423511993'},
#  {'resource_type': 'DocumentReference',
#   'id': '0f1b249c-ab9d-466e-c62d-5479a237170f',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:3a86e89a-e4d4-bc2e-e81c-365423511993'}]},
#  {'resource_type': 'Claim', 'id': '6e791560-da4f-1dfe-56b4-5b7eae09bb9e'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '15b636d8-0886-cd51-72d4-1a5c20fbd27c',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '6e791560-da4f-1dfe-56b4-5b7eae09bb9e'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '09d6ad28-9a5b-882b-e35c-5d90d204d020',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '09d6ad28-9a5b-882b-e35c-5d90d204d020'}]},
#  {'resource_type': 'Observation',
#   'id': '22b1cca0-22c2-468a-d155-3a353413c1c4'},
#  {'resource_type': 'Observation',
#   'id': 'dc82ace6-4e4d-29c4-238b-764e56033124'},
#  {'resource_type': 'Observation',
#   'id': '62123b71-9e99-8fec-ca0a-a261a5010085'},
#  {'resource_type': 'Observation',
#   'id': 'ee4b813e-8701-797a-4226-b84d0cc982f8'},
#  {'resource_type': 'Observation',
#   'id': 'f3e20fbe-dd4b-252a-c580-5354d14554df'},
#  {'resource_type': 'Observation',
#   'id': 'a7bdc90f-475c-0624-e98b-d57b280db8b0'},
#  {'resource_type': 'Observation',
#   'id': 'c65e776a-f7a2-785c-d4d5-0e1296537bf9'},
#  {'resource_type': 'Observation',
#   'id': '989ce7e2-e73b-d73b-50be-359714e0a8a3'},
#  {'resource_type': 'Observation',
#   'id': '30567c4e-f512-da7f-ab12-52b728ad867a'},
#  {'resource_type': 'Observation',
#   'id': '9ceb687f-2e8c-5d5f-afb0-5cb36f05b0ec'},
#  {'resource_type': 'Observation',
#   'id': 'f1470eb6-b716-f3f1-b115-aeec88c24510'},
#  {'resource_type': 'Observation',
#   'id': '94ad2f59-9a53-f2d0-23e3-a1b914ea6bea'},
#  {'resource_type': 'Observation',
#   'id': 'a3fddfe3-86d6-ccf9-56e5-5c77485bc4ed'},
#  {'resource_type': 'Observation',
#   'id': '7dcd7d1d-57e1-ebf5-3bd8-34e42a3074c0'},
#  {'resource_type': 'Observation',
#   'id': 'bfcd0c8b-3156-663d-868a-2fac1bb0dc44'},
#  {'resource_type': 'Observation',
#   'id': '82d2c127-247e-37d9-f507-7642e2fb3bd6'},
#  {'resource_type': 'Observation',
#   'id': 'fb999754-24ae-e149-c5c8-d5f4416bc6d1'},
#  {'resource_type': 'Observation',
#   'id': '7c4a3c0b-ea3c-90a9-f562-9c394673eb56'},
#  {'resource_type': 'Observation',
#   'id': '454eb35c-0f14-390f-2554-644d2537d24f'},
#  {'resource_type': 'Observation',
#   'id': '76157210-a4d5-3c37-2e8f-a9ffb3355bb0'},
#  {'resource_type': 'Observation',
#   'id': '877fdeb3-16a9-8a62-9554-35c8c0a81aff'},
#  {'resource_type': 'Observation',
#   'id': '05036db1-d3a5-5c7a-e65e-b620d4921816'},
#  {'resource_type': 'Observation',
#   'id': '2643ccde-df65-ec7a-9857-1a0e26895827'},
#  {'resource_type': 'Observation',
#   'id': '9c5fd21c-8038-d00c-5531-80fce3e67301'},
#  {'resource_type': 'Observation',
#   'id': '73922157-3a8b-d973-970d-d3d454f0b891'},
#  {'resource_type': 'Observation',
#   'id': '9e61bdb3-aaff-a2aa-a84f-5b468568aaaa'},
#  {'resource_type': 'Observation',
#   'id': '5aadfa08-8975-26cd-4866-e76ae299cf08'},
#  {'resource_type': 'Observation',
#   'id': '95a47c8e-c211-0db8-3b5f-5c884c291d91'},
#  {'resource_type': 'Observation',
#   'id': '296749d4-93b5-8ded-bae5-b9325c658ede'},
#  {'resource_type': 'Observation',
#   'id': 'e1140af7-a01e-08ba-4982-e999f5348efa'},
#  {'resource_type': 'Observation',
#   'id': 'ad3d030f-ced5-c49b-8d4e-fc21300c5869'},
#  {'resource_type': 'Observation',
#   'id': '1ef767ed-73f5-69dc-2bca-8b2db60a7b6b'},
#  {'resource_type': 'Observation',
#   'id': 'd1aa1201-dc29-2582-ce04-703fd1551581'},
#  {'resource_type': 'Observation',
#   'id': 'cf02b7a0-db3b-966c-77ff-14458ed97d30'},
#  {'resource_type': 'Observation',
#   'id': '8c272768-4f7f-e8b4-c9a9-f12e5f636604'},
#  {'resource_type': 'Observation',
#   'id': 'f69b35fb-6d37-c35a-f7f9-18bb6d33c0d7'},
#  {'resource_type': 'Observation',
#   'id': '29ab52f1-a7b7-ec23-caed-d49b6feedc53'},
#  {'resource_type': 'Observation',
#   'id': '0db6f914-ecd8-c5be-7f00-b3b8102d89b4'},
#  {'resource_type': 'Procedure', 'id': '00b56dc5-c06e-0c29-6e8e-98cdce7549d2'},
#  {'resource_type': 'Procedure', 'id': '1e0283be-5b53-7352-17ef-9e3d0b17c65e'},
#  {'resource_type': 'Procedure', 'id': '222854fb-ea52-0c01-b7f7-e31eedba1b6b'},
#  {'resource_type': 'Procedure', 'id': 'c93627f9-2efc-92f4-e40f-959cf848b530'},
#  {'resource_type': 'Procedure', 'id': 'e283f41f-45df-0e4b-8410-ce7d8224c60c'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'dec5397c-0440-5d26-47ef-11ffe9a498c9'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'fc451fb1-f27a-9d8c-5115-89eb3bd04324'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '44511032-38d9-8c8e-b0a6-4ce268d87c8d'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '9b763fa9-223c-44ac-9396-46fadf5d9d2a'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '3789dab9-03a9-fe76-5146-9791e5790921'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'd9bac9ec-28df-b776-f9f5-785a0cdb8c16'},
#  {'resource_type': 'CareTeam', 'id': '5b6740e4-c5d6-e34d-b56e-01b4437768f2'},
#  {'resource_type': 'CarePlan', 'id': '115f8cd8-2aa3-8b1b-10ff-6042dc5521e6'},
#  {'resource_type': 'DiagnosticReport',
#   'id': '95e2d63a-840a-7f24-eb39-4fbf589e3caf'},
#  {'resource_type': 'DocumentReference',
#   'id': 'f539c9bd-2616-7eaf-b574-ef0a17d9871b',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:95e2d63a-840a-7f24-eb39-4fbf589e3caf'}]},
#  {'resource_type': 'Claim', 'id': '7e9e5c76-b0fd-7a31-540e-417f8c089fcb'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '8a5f1f60-b215-53ab-9fa3-f192430ec739',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '7e9e5c76-b0fd-7a31-540e-417f8c089fcb'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Encounter',
#   'id': '021fd605-b4a9-c14f-e0f8-289676c53cfc',
#   'identifier': [{'use': 'official',
#     'system': 'https://github.com/synthetichealth/synthea',
#     'value': '021fd605-b4a9-c14f-e0f8-289676c53cfc'}]},
#  {'resource_type': 'Observation',
#   'id': 'f800447a-ef7b-3669-1f66-8fd6d0a1ad4b'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'e88d688c-e5c8-f67d-9c90-cef3591772bf'},
#  {'resource_type': 'DiagnosticReport',
#   'id': 'a0f09238-dc46-b6ab-d024-1b65de24b05c'},
#  {'resource_type': 'DocumentReference',
#   'id': '22130f5f-fd80-715b-e9af-ad61740887d1',
#   'identifier': [{'system': 'urn:ietf:rfc:3986',
#     'value': 'urn:uuid:a0f09238-dc46-b6ab-d024-1b65de24b05c'}]},
#  {'resource_type': 'Claim', 'id': '21a45eba-6c35-5015-a5ad-2ddf8f2feffe'},
#  {'resource_type': 'ExplanationOfBenefit',
#   'id': '165c1e0b-675c-cfb0-cb59-71fadb3aefb7',
#   'identifier': [{'system': 'https://bluebutton.cms.gov/resources/variables/clm_id',
#     'value': '21a45eba-6c35-5015-a5ad-2ddf8f2feffe'},
#    {'system': 'https://bluebutton.cms.gov/resources/identifier/claim-group',
#     'value': '99999999999'}]},
#  {'resource_type': 'Provenance', 'id': '9cb02794-8917-82ae-340d-177aa8d440c7'}]

# %% [markdown]
# ## Tabular formation( dataframes)

# %%
df = pd.DataFrame(final_list, columns =["resourceType","id","identifier","active",
"telecom","name","gender", "birthDate", "deceasedBoolean","deceasedDateTime" ,"address" , 
 "organization","period","maritalStatus","communication" ])

# %%
df

# %% [markdown]
# ## Mongo DB

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]

# %%
mycol = mydb["resources"]

# %%
x =mycol.insert_one(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ba364f52db49> in <module>
# ----> 1 x =mycol.insert_one(data)
#
# NameError: name 'data' is not defined

# %%
for y in mycol.find():
    print(y)

# %% [markdown]
# ### Tests

# %%
df_json = pd.read_json(file)

# %%
df_json["entry"][0][]

# %%
for i in range(6):
    print(df_json["entry"][i]["resource"])
    if df_json["entry"][i]["resource"]["resourceType"] == "Patient":
        df_json["entry"][i]["resource"]["id"]
